# %% [markdown]
# # Character-Level LSTM in PyTorch
#
# In this notebook, I'll construct a character-level LSTM with PyTorch. The network will train character by character on some text, then generate new text character by character. As an example, I will train on Anna Karenina. **This model will be able to generate new text based on the text from the book!**
#
# This network is based off of Andrej Karpathy's [post on RNNs](http://karpathy.github.io/2015/05/21/rnn-effectiveness/) and [implementation in Torch](https://github.com/karpathy/char-rnn). Below is the general architecture of the character-wise RNN.
#
# <img src="assets/charseq.jpeg" width="500">

# %% [markdown]
# First let's load in our required resources for data loading and model creation.

# %%
import numpy as np
import torch
from torch import nn
import torch.nn.functional as F

# %% [markdown]
# ## Load in Data
#
# Then, we'll load the Anna Karenina text file and convert it into integers for our network to use.
#
# ### Tokenization
#
# In the second cell, below, I'm creating a couple **dictionaries** to convert the characters to and from integers. Encoding the characters as integers makes it easier to use as input in the network.

# %%
# open text file and read in data as `text`
with open('data/anna.txt', 'r') as f:
    text = f.read()

# %% [markdown]
# Now we have the text, encode it as integers.

# %%
# encode the text and map each character to an integer and vice versa

# we create two dictonaries:
# 1. int2char, which maps integers to characters
# 2. char2int, which maps characters to unique integers
chars = tuple(set(text))
int2char = dict(enumerate(chars))
char2int = {ch: ii for ii, ch in int2char.items()}
encoded = np.array([char2int[ch] for ch in text])

# %% [markdown]
# Let's check out the first 100 characters, make sure everything is peachy. According to the [American Book Review](http://americanbookreview.org/100bestlines.asp), this is the 6th best first line of a book ever.

# %%
text[:100]
# Out:
# 'Chapter 1\n\n\nHappy families are all alike; every unhappy family is unhappy in its own\nway.\n\nEverythin'

# %% [markdown]
# And we can see those same characters encoded as integers.

# %%
encoded[:100]
# Out:
# array([ 5, 68, 30, 28, 73, 55, 64, 33, 78, 37, 37, 37,  8, 30, 28, 28, 22,
#        33, 70, 30, 82, 75, 25, 75, 55, 40, 33, 30, 64, 55, 33, 30, 25, 25,
#        33, 30, 25, 75, 56, 55, 79, 33, 55, 35, 55, 64, 22, 33, 10, 29, 68,
#        30, 28, 28, 22, 33, 70, 30, 82, 75, 25, 22, 33, 75, 40, 33, 10, 29,
#        68, 30, 28, 28, 22, 33, 75, 29, 33, 75, 73, 40, 33, 61, 39, 29, 37,
#        39, 30, 22, 11, 37, 37, 58, 35, 55, 64, 22, 73, 68, 75, 29])

# %% [markdown]
# ## Pre-processing the data
#
# As you can see in our char-RNN image above, our LSTM expects an input that is **one-hot encoded** meaning that each character is converted into an intgere (via our created dictionary) and *then* converted into a column vector where only it's corresponsing integer index will have the value of 1 and the rest of the vector will be filled with 0's. Since we're one-hot encoding the data, let's make a function to do that!

# %%
def one_hot_encode(arr, n_labels):
    
    # Initialize the the encoded array
    one_hot = np.zeros((np.multiply(*arr.shape), n_labels), dtype=np.float32)
    
    # Fill the appropriate elements with ones
    one_hot[np.arange(one_hot.shape[0]), arr.flatten()] = 1.
    
    # Finally reshape it to get back to the original array
    one_hot = one_hot.reshape((*arr.shape, n_labels))
    
    return one_hot

# %% [markdown]
# ## Making training mini-batches
#
#
# To train on this data, we also want to create mini-batches for training. Remember that we want our batches to be multiple sequences of some desired number of sequence steps. Considering a simple example, our batches would look like this:
#
# <img src="assets/sequence_batching@1x.png" width=500px>
#
#
# <br>
#
# In this example, we'll take the encoded characters (passed in as the `arr` parameter) and split them into multiple sequences, given by `n_seqs` (also refered to as "batch size" in other places). Each of those sequences will be `n_steps` long.
#
# ### Creating Batches
#
# **1. The first thing we need to do is discard some of the text so we only have completely full batches. **
#
# Each batch contains $N \times M$ characters, where $N$ is the batch size (the number of sequences) and $M$ is the number of steps. Then, to get the total number of batches, $K$, we can make from the array `arr`, you divide the length of `arr` by the number of characters per batch. Once you know the number of batches, you can get the total number of characters to keep from `arr`, $N * M * K$.
#
# **2. After that, we need to split `arr` into $N$ sequences. **
#
# You can do this using `arr.reshape(size)` where `size` is a tuple containing the dimensions sizes of the reshaped array. We know we want $N$ sequences, so let's make that the size of the first dimension. For the second dimension, you can use `-1` as a placeholder in the size, it'll fill up the array with the appropriate data for you. After this, you should have an array that is $N \times (M * K)$.
#
# **3. Now that we have this array, we can iterate through it to get our batches. **
#
# The idea is each batch is a $N \times M$ window on the $N \times (M * K)$ array. For each subsequent batch, the window moves over by `n_steps`. We also want to create both the input and target arrays. Remember that the targets are the inputs shifted over one character. The way I like to do this window is use `range` to take steps of size `n_steps` from $0$ to `arr.shape[1]`, the total number of steps in each sequence. That way, the integers you get from `range` always point to the start of a batch, and each window is `n_steps` wide.
#
# > **TODO:** Write the code for creating batches in the function below. The exercises in this notebook _will not be easy_. I've provided a notebook with solutions alongside this notebook. If you get stuck, checkout the solutions. The most important thing is that you don't copy and paste the code into here, **type out the solution code yourself.**

# %%
def get_batches(arr, n_seqs, n_steps):
    '''Create a generator that returns batches of size
       n_seqs x n_steps from arr.
       
       Arguments
       ---------
       arr: Array you want to make batches from
       n_seqs: Batch size, the number of sequences per batch
       n_steps: Number of sequence steps per batch
    '''
    
    # Get the number of characters per batch (total number of characters for every batch)
    batch_size = n_seqs * n_steps
    
    ## TODO: Get the number of batches we can make
    total_number_of_chars = arr.shape[0]
    n_batches = total_number_of_chars // batch_size
    
    ## TODO: Keep only enough characters to make full batches
    arr = arr[: n_batches * batch_size]
    
    ## TODO: Reshape into batch_size rows: (number_sequences x sequence_len * n_batches)
    arr = arr.reshape((n_seqs, -1))
    
    ## TODO: Make batches: [n_seqs x n_steps] or [n_batches x seq_Len] where n_batches is the number of batches created
    for n in range(0, arr.shape[1], n_steps):
        # The features (from all the batches, take windows of n_batches x seq_len to feed the network)
        x = arr[:, n : n + n_steps]
        
        # The targets, shifted by one
        y = np.zeros_like(x)
        if (n + 1) + n_steps >= arr.shape[1]: 
            y[:, : -1] = arr[:, n + 1 : (n + 1) + n_steps]
            y[:, -1] = arr[:, 0]
        else:
            y = arr[:, n + 1 : (n + 1) + n_steps]
            
        yield x, y

# %% [markdown]
# ### Test Your Implementation
#
# Now I'll make some data sets and we can check out what's going on as we batch data. Here, as an example, I'm going to use a batch size of 10 and 50 sequence steps.

# %%
batches = get_batches(encoded, 10, 50)
x, y = next(batches)

print('Shape: n_batches x seq_len or n_seqs x n_steps')
print(x.shape)
print(y.shape)
# Out:
# Shape: n_batches x seq_len or n_seqs x n_steps
# (10, 50)
# (10, 50)

# %%
print('x\n', x[:10, :10])
print('\ny\n', y[:10, :10])
# Out:
# x
#  [[ 5 68 30 28 73 55 64 33 78 37]
#  [33 30 82 33 29 61 73 33 50 61]
#  [35 75 29 11 37 37 57 76 55 40]
#  [29 33  3 10 64 75 29 50 33 68]
#  [33 75 73 33 75 40 72 33 40 75]
#  [33 21 73 33 39 30 40 37 61 29]
#  [68 55 29 33  1 61 82 55 33 70]
#  [79 33 12 10 73 33 29 61 39 33]
#  [73 33 75 40 29 54 73 11 33 51]
#  [33 40 30 75  3 33 73 61 33 68]]
#
# y
#  [[68 30 28 73 55 64 33 78 37 37]
#  [30 82 33 29 61 73 33 50 61 75]
#  [75 29 11 37 37 57 76 55 40 72]
#  [33  3 10 64 75 29 50 33 68 75]
#  [75 73 33 75 40 72 33 40 75 64]
#  [21 73 33 39 30 40 37 61 29 25]
#  [55 29 33  1 61 82 55 33 70 61]
#  [33 12 10 73 33 29 61 39 33 40]
#  [33 75 40 29 54 73 11 33 51 68]
#  [40 30 75  3 33 73 61 33 68 55]]

# %% [markdown]
# If you implemented `get_batches` correctly, the above output should look something like
# ```
# x
#  [[55 63 69 22  6 76 45  5 16 35]
#  [ 5 69  1  5 12 52  6  5 56 52]
#  [48 29 12 61 35 35  8 64 76 78]
#  [12  5 24 39 45 29 12 56  5 63]
#  [ 5 29  6  5 29 78 28  5 78 29]
#  [ 5 13  6  5 36 69 78 35 52 12]
#  [63 76 12  5 18 52  1 76  5 58]
#  [34  5 73 39  6  5 12 52 36  5]
#  [ 6  5 29 78 12 79  6 61  5 59]
#  [ 5 78 69 29 24  5  6 52  5 63]]
#
# y
#  [[63 69 22  6 76 45  5 16 35 35]
#  [69  1  5 12 52  6  5 56 52 29]
#  [29 12 61 35 35  8 64 76 78 28]
#  [ 5 24 39 45 29 12 56  5 63 29]
#  [29  6  5 29 78 28  5 78 29 45]
#  [13  6  5 36 69 78 35 52 12 43]
#  [76 12  5 18 52  1 76  5 58 52]
#  [ 5 73 39  6  5 12 52 36  5 78]
#  [ 5 29 78 12 79  6 61  5 59 63]
#  [78 69 29 24  5  6 52  5 63 76]]
#  ```
#  although the exact numbers will be different. Check to make sure the data is shifted over one step for `y`.

# %% [markdown]
# ---
# ## Defining the network with PyTorch
#
# Below is where you'll define the network. We'll break it up into parts so it's easier to reason about each bit. Then we can connect them up into the whole network.
#
# <img src="assets/charRNN.png" width=500px>
#
# Next, you'll use PyTorch to define the architecture of the network. We start by defining the layers and operations we want. Then, define a method for the forward pass. You've also been given a method for predicting characters.

# %% [markdown]
# ### Model Structure
#
# In `__init__` the suggested structure is as follows:
# * Create and store the necessary dictionaries (this has been done for you)
# * Define an LSTM layer that takes as params: an input size (<b>the number of characters</b>), a hidden layer size `n_hidden`, a number of layers `n_layers`, a dropout probability `drop_prob`, and a batch_first boolean (True, since we are batching)
# * Define a dropout layer with `dropout_prob`
# * Define a fully-connected layer with params: input size `n_hidden` and output size (the number of characters)
# * Finally, initialize the weights (again, this has been given)
#
# Note that some parameters have been named and given in the `__init__` function, and we use them and store them by doing something like `self.drop_prob = drop_prob`.

# %% [markdown]
# ---
# ### LSTM Inputs/Outputs
#
# You can create a basic LSTM cell as follows
#
# ```python
# self.lstm = nn.LSTM(input_size, n_hidden, n_layers,
#                             dropout=drop_prob, batch_first=True)
# ```
#
# where `input_size` is the <b>number of characters</b> this cell expects to see as sequential input, and `n_hidden` is the number of units in the hidden layers in the cell. And we can add dropout by adding a dropout parameter with a specified probability; this will automatically add dropout to the inputs or outputs. Finally, in the `forward` function, we can stack up the LSTM cells into layers using `.view`. With this, you pass in a list of cells and it will send the output of one cell into the next cell.
#
# We also need to create an initial cell state of all zeros. This is done like so
#
# ```python
# self.init_weights()
# ```

# %%
class CharRNN(nn.Module):
    
    def __init__(self, tokens, n_steps=100, n_hidden=256, n_layers=2,
                               drop_prob=0.5, lr=0.001):
        super().__init__()
        self.drop_prob = drop_prob
        self.n_layers = n_layers
        self.n_hidden = n_hidden
        self.lr = lr
        
        # creating character dictionaries
        self.chars = tokens
        self.int2char = dict(enumerate(self.chars))
        self.char2int = {ch: ii for ii, ch in self.int2char.items()}
        
        ## TODO: define the LSTM, self.lstm: batch_first means (batch, seq, feature)
        self.lstm = nn.LSTM(input_size=len(self.chars), hidden_size=self.n_hidden, num_layers=self.n_layers, dropout=self.drop_prob, batch_first=True)
        ## TODO: define a dropout layer, self.dropout
        self.dropout = nn.Dropout(p=self.drop_prob)
        ## TODO: define the final, fully-connected output layer, self.fc
        self.fc = nn.Linear(in_features=self.n_hidden, out_features=len(self.chars))
        # initialize the weights
        self.init_weights()
      
    # Note: x is [batch x seq_len x input_size]
    def forward(self, x, hc):
        ''' Forward pass through the network. 
            These inputs are x, and the hidden/cell state `hc`. '''
        
        ## TODO: Get x, and the new hidden state (h, c) from the lstm
        x, (h, c) = self.lstm(x, hc)
        ## TODO: pass x through a droupout layer
        x = self.dropout(x)
        # Stack up LSTM outputs using view
        x = x.view(x.size(0) * x.size(1), self.n_hidden)
        
        ## TODO: put x through the fully-connected layer
        x = self.fc(x)
        # return x and the hidden state (h, c)
        return x, (h, c)
    
    
    def predict(self, char, h=None, cuda=False, top_k=None):
        ''' Given a character, predict the next character.
        
            Returns the predicted character and the hidden state.
        '''
        if cuda:
            self.cuda()
        else:
            self.cpu()
        
        if h is None:
            h = self.init_hidden(1)
        
        x = np.array([[self.char2int[char]]])
        x = one_hot_encode(x, len(self.chars))
        inputs = torch.from_numpy(x)
        if cuda:
            inputs = inputs.cuda()
        
        h = tuple([each.data for each in h])
        out, h = self.forward(inputs, h)

        p = F.softmax(out, dim=1).data
        if cuda:
            p = p.cpu()
        
        if top_k is None:
            top_ch = np.arange(len(self.chars))
        else:
            p, top_ch = p.topk(top_k)
            top_ch = top_ch.numpy().squeeze()
        
        p = p.numpy().squeeze()
        char = np.random.choice(top_ch, p=p/p.sum())
            
        return self.int2char[char], h
    
    def init_weights(self):
        ''' Initialize weights for fully connected layer '''
        initrange = 0.1
        
        # Set bias tensor to all zeros
        self.fc.bias.data.fill_(0)
        # FC weights as random uniform
        self.fc.weight.data.uniform_(-1, 1)
        
    def init_hidden(self, n_seqs):
        ''' Initializes hidden state '''
        # Create two new tensors with sizes n_layers x n_seqs x n_hidden,
        # initialized to zero, for hidden state and cell state of LSTM
        weight = next(self.parameters()).data
        return (weight.new(self.n_layers, n_seqs, self.n_hidden).zero_(),
                weight.new(self.n_layers, n_seqs, self.n_hidden).zero_())

# %% [markdown]
# ### A note on the `predict`  function
#
# The output of our RNN is from a fully-connected layer and it outputs a **distribution of next-character scores**.
#
# To actually get the next character, we apply a softmax function, which gives us a *probability* distribution that we can then sample to predict the next character.

# %%
## ---- keep notebook from crashing during training --- ##
import os
#import requests
import time

def train(net, data, epochs=10, n_seqs=10, n_steps=50, lr=0.001, clip=5, val_frac=0.1, cuda=False, print_every=10):
    ''' Training a network 
    
        Arguments
        ---------
        
        net: CharRNN network
        data: text data to train the network
        epochs: Number of epochs to train
        n_seqs: Number of mini-sequences per mini-batch, aka batch size
        n_steps: Number of character steps per mini-batch
        lr: learning rate
        clip: gradient clipping
        val_frac: Fraction of data to hold out for validation
        cuda: Train with CUDA on a GPU
        print_every: Number of steps for printing training and validation loss
    
    '''
    
    net.train()
    opt = torch.optim.Adam(net.parameters(), lr=lr)
    criterion = nn.CrossEntropyLoss()
    
    # create training and validation data
    val_idx = int(len(data) * (1 - val_frac))
    data, val_data = data[: val_idx], data[val_idx :]
    
    if cuda:
        net.cuda()
    
    counter = 0
    n_chars = len(net.chars)
    
    print('Number of characters in vocabulary: ', n_chars)
    
    old_time = time.time()

    for e in range(epochs):
        h = net.init_hidden(n_seqs)
        for x, y in get_batches(data, n_seqs, n_steps):
            
            if time.time() - old_time > 60:
                old_time = time.time()
                #requests.request("POST", 
                #                 "https://nebula.udacity.com/api/v1/remote/keep-alive", 
                #                 headers={'Authorization': "STAR " + response.text})
            
            counter += 1
            
            # One-hot encode our data and make them Torch tensors
            x = one_hot_encode(x, n_chars)
            inputs, targets = torch.from_numpy(x), torch.from_numpy(y).long()
            
            if cuda:
                inputs, targets = inputs.cuda(), targets.cuda()
            
            # Creating new variables for the hidden state, otherwise
            # we'd backprop through the entire training history
            h = tuple([each.data for each in h])

            net.zero_grad()
            
            output, h = net.forward(inputs, h)
            loss = criterion(output, targets.view(n_seqs * n_steps))

            loss.backward()
            
            # `clip_grad_norm` helps prevent the exploding gradient problem in RNNs / LSTMs.
            nn.utils.clip_grad_norm_(net.parameters(), clip)

            opt.step()
            
            if counter % print_every == 0:
                
                # Get validation loss
                val_h = net.init_hidden(n_seqs)
                val_losses = []
                for x, y in get_batches(val_data, n_seqs, n_steps):
                    # One-hot encode our data and make them Torch tensors
                    x = one_hot_encode(x, n_chars)
                    x, y = torch.from_numpy(x), torch.from_numpy(y)
                    
                    # Creating new variables for the hidden state, otherwise
                    # we'd backprop through the entire training history
                    val_h = tuple([each.data for each in val_h])
                    
                    inputs, targets = x, y.long()
                    
                    if cuda:
                        inputs, targets = inputs.cuda(), targets.cuda()

                    output, val_h = net.forward(inputs, val_h)
                    
                    val_loss = criterion(output, targets.view(n_seqs * n_steps))
                
                    val_losses.append(val_loss.item())
                
                print("Epoch: {}/{}...".format(e+1, epochs),
                      "Step: {}...".format(counter),
                      "Loss: {:.4f}...".format(loss.item()),
                      "Val Loss: {:.4f}".format(np.mean(val_losses)))

# %% [markdown]
# ## Time to train
#
# Now we can actually train the network. First we'll create the network itself, with some given hyperparameters. Then, define the mini-batches sizes (number of sequences and number of steps), and start the training. With the train function, we can set the number of epochs, the learning rate, and other parameters. Also, we can run the training on a GPU by setting `cuda=True`.

# %%
if 'net' in locals():
    del net

# %%
# define and print the net
net = CharRNN(chars, n_hidden=512, n_layers=2)
print(net)
# Out:
# CharRNN(
#   (lstm): LSTM(83, 512, num_layers=2, batch_first=True, dropout=0.5)
#   (dropout): Dropout(p=0.5, inplace=False)
#   (fc): Linear(in_features=512, out_features=83, bias=True)
# )

# %%
n_seqs, n_steps = 128, 100

# you may change cuda to True if you plan on using a GPU!
# also, if you do, please INCREASE the epochs to 25

# Open the training log file.
log_file = 'training_log.txt'
f = open(log_file, 'w')

#response = requests.request("GET", "http://metadata.google.internal/computeMetadata/v1/instance/attributes/keep_alive_token", headers={"Metadata-Flavor":"Google"})

# TRAIN
train(net, encoded, epochs=25, n_seqs=n_seqs, n_steps=n_steps, lr=0.001, cuda=True, print_every=2)

# Close the training log file.
f.close()
# Out:
# Number of characters in vocabulary:  83
# Epoch: 1/25... Step: 2... Loss: 2.4247... Val Loss: 2.4047
# Epoch: 1/25... Step: 4... Loss: 2.3276... Val Loss: 2.3805
# Epoch: 1/25... Step: 6... Loss: 2.3012... Val Loss: 2.3482
# Epoch: 1/25... Step: 8... Loss: 2.3154... Val Loss: 2.3284
# Epoch: 1/25... Step: 10... Loss: 2.2872... Val Loss: 2.3224
# Epoch: 1/25... Step: 12... Loss: 2.2793... Val Loss: 2.3116
# Epoch: 1/25... Step: 14... Loss: 2.2543... Val Loss: 2.3094
# Epoch: 1/25... Step: 16... Loss: 2.2513... Val Loss: 2.2988
# Epoch: 1/25... Step: 18... Loss: 2.2428... Val Loss: 2.2919
# Epoch: 1/25... Step: 20... Loss: 2.2412... Val Loss: 2.2874
# Epoch: 1/25... Step: 22... Loss: 2.2349... Val Loss: 2.2818
# Epoch: 1/25... Step: 24... Loss: 2.2176... Val Loss: 2.2771
# Epoch: 1/25... Step: 26... Loss: 2.2207... Val Loss: 2.2760
# Epoch: 1/25... Step: 28... Loss: 2.2262... Val Loss: 2.2675
# Epoch: 1/25... Step: 30... Loss: 2.2342... Val Loss: 2.2636
# Epoch: 1/25... Step: 32... Loss: 2.2030... Val Loss: 2.2590
# Epoch: 1/25... Step: 34... Loss: 2.2002... Val Loss: 2.2605
# Epoch: 1/25... Step: 36... Loss: 2.1919... Val Loss: 2.2527
# Epoch: 1/25... Step: 38... Loss: 2.1979... Val Loss: 2.2496
# Epoch: 1/25... Step: 40... Loss: 2.1755... Val Loss: 2.2513
# Epoch: 1/25... Step: 42... Loss: 2.1634... Val Loss: 2.2661
# Epoch: 1/25... Step: 44... Loss: 2.1648... Val Loss: 2.2751
# Epoch: 1/25... Step: 46... Loss: 2.1714... Val Loss: 2.2842
# Epoch: 1/25... Step: 48... Loss: 2.1309... Val Loss: 2.2698
# Epoch: 1/25... Step: 50... Loss: 2.1948... Val Loss: 2.2397
# Epoch: 1/25... Step: 52... Loss: 2.1346... Val Loss: 2.2323
# Epoch: 1/25... Step: 54... Loss: 2.1399... Val Loss: 2.2219
# Epoch: 1/25... Step: 56... Loss: 2.1416... Val Loss: 2.2135
# Epoch: 1/25... Step: 58... Loss: 2.1184... Val Loss: 2.2067
# Epoch: 1/25... Step: 60... Loss: 2.1169... Val Loss: 2.2030
# Epoch: 1/25... Step: 62... Loss: 2.1593... Val Loss: 2.1962
# Epoch: 1/25... Step: 64... Loss: 2.1080... Val Loss: 2.1940
# Epoch: 1/25... Step: 66... Loss: 2.0946... Val Loss: 2.1978
# Epoch: 1/25... Step: 68... Loss: 2.1216... Val Loss: 2.1923
# Epoch: 1/25... Step: 70... Loss: 2.1049... Val Loss: 2.1896
# Epoch: 1/25... Step: 72... Loss: 2.1329... Val Loss: 2.1976
# Epoch: 1/25... Step: 74... Loss: 2.1265... Val Loss: 2.1788
# Epoch: 1/25... Step: 76... Loss: 2.0709... Val Loss: 2.1724
# Epoch: 1/25... Step: 78... Loss: 2.1162... Val Loss: 2.1703
# Epoch: 1/25... Step: 80... Loss: 2.0703... Val Loss: 2.1615
# Epoch: 1/25... Step: 82... Loss: 2.0372... Val Loss: 2.1563
# Epoch: 1/25... Step: 84... Loss: 2.0786... Val Loss: 2.1548
# Epoch: 1/25... Step: 86... Loss: 2.0732... Val Loss: 2.1458
# Epoch: 1/25... Step: 88... Loss: 2.0626... Val Loss: 2.1439
# Epoch: 1/25... Step: 90... Loss: 2.0848... Val Loss: 2.1453
# Epoch: 1/25... Step: 92... Loss: 2.0719... Val Loss: 2.1394
# Epoch: 1/25... Step: 94... Loss: 2.0527... Val Loss: 2.1392
# Epoch: 1/25... Step: 96... Loss: 2.0487... Val Loss: 2.1317
# Epoch: 1/25... Step: 98... Loss: 2.0611... Val Loss: 2.1268
# Epoch: 1/25... Step: 100... Loss: 2.0440... Val Loss: 2.1258
# Epoch: 1/25... Step: 102... Loss: 2.0592... Val Loss: 2.1226
# Epoch: 1/25... Step: 104... Loss: 1.9924... Val Loss: 2.1150
# Epoch: 1/25... Step: 106... Loss: 2.0165... Val Loss: 2.1196
# Epoch: 1/25... Step: 108... Loss: 2.0248... Val Loss: 2.1112
# Epoch: 1/25... Step: 110... Loss: 2.0210... Val Loss: 2.1079
# Epoch: 1/25... Step: 112... Loss: 2.0236... Val Loss: 2.1030
# Epoch: 1/25... Step: 114... Loss: 2.0347... Val Loss: 2.1016
# Epoch: 1/25... Step: 116... Loss: 2.0150... Val Loss: 2.0985
# Epoch: 1/25... Step: 118... Loss: 2.0070... Val Loss: 2.0928
# Epoch: 1/25... Step: 120... Loss: 1.9753... Val Loss: 2.0889
# Epoch: 1/25... Step: 122... Loss: 1.9776... Val Loss: 2.0888
# Epoch: 1/25... Step: 124... Loss: 2.0192... Val Loss: 2.0821
# Epoch: 1/25... Step: 126... Loss: 2.0000... Val Loss: 2.0855
# Epoch: 1/25... Step: 128... Loss: 1.9926... Val Loss: 2.0917
# Epoch: 1/25... Step: 130... Loss: 2.0186... Val Loss: 2.0808
# Epoch: 1/25... Step: 132... Loss: 1.9987... Val Loss: 2.0783
# Epoch: 1/25... Step: 134... Loss: 1.9726... Val Loss: 2.0788
# Epoch: 1/25... Step: 136... Loss: 2.0038... Val Loss: 2.0599
# Epoch: 1/25... Step: 138... Loss: 1.9758... Val Loss: 2.0616
# Epoch: 2/25... Step: 140... Loss: 2.0091... Val Loss: 2.0552
# Epoch: 2/25... Step: 142... Loss: 1.9867... Val Loss: 2.0494
# Epoch: 2/25... Step: 144... Loss: 1.9660... Val Loss: 2.0452
# Epoch: 2/25... Step: 146... Loss: 1.9655... Val Loss: 2.0445
# Epoch: 2/25... Step: 148... Loss: 1.9725... Val Loss: 2.0406
# Epoch: 2/25... Step: 150... Loss: 1.9801... Val Loss: 2.0389
# Epoch: 2/25... Step: 152... Loss: 1.9772... Val Loss: 2.0399
# Epoch: 2/25... Step: 154... Loss: 1.9595... Val Loss: 2.0385
# Epoch: 2/25... Step: 156... Loss: 1.9578... Val Loss: 2.0328
# Epoch: 2/25... Step: 158... Loss: 1.9457... Val Loss: 2.0337
# Epoch: 2/25... Step: 160... Loss: 1.9842... Val Loss: 2.0258
# Epoch: 2/25... Step: 162... Loss: 1.9503... Val Loss: 2.0238
# Epoch: 2/25... Step: 164... Loss: 1.9244... Val Loss: 2.0188
# Epoch: 2/25... Step: 166... Loss: 1.9354... Val Loss: 2.0143
# Epoch: 2/25... Step: 168... Loss: 1.9465... Val Loss: 2.0127
# Epoch: 2/25... Step: 170... Loss: 1.9567... Val Loss: 2.0081
# Epoch: 2/25... Step: 172... Loss: 1.8968... Val Loss: 2.0070
# Epoch: 2/25... Step: 174... Loss: 1.9337... Val Loss: 2.0063
# Epoch: 2/25... Step: 176... Loss: 1.9487... Val Loss: 2.0031
# Epoch: 2/25... Step: 178... Loss: 1.9223... Val Loss: 2.0019
# Epoch: 2/25... Step: 180... Loss: 1.9205... Val Loss: 2.0070
# Epoch: 2/25... Step: 182... Loss: 1.8745... Val Loss: 2.0012
# Epoch: 2/25... Step: 184... Loss: 1.9035... Val Loss: 1.9954
# Epoch: 2/25... Step: 186... Loss: 1.9185... Val Loss: 1.9975
# Epoch: 2/25... Step: 188... Loss: 1.9016... Val Loss: 1.9911
# Epoch: 2/25... Step: 190... Loss: 1.8734... Val Loss: 1.9890
# Epoch: 2/25... Step: 192... Loss: 1.9112... Val Loss: 1.9897
# Epoch: 2/25... Step: 194... Loss: 1.8620... Val Loss: 1.9854
# Epoch: 2/25... Step: 196... Loss: 1.8739... Val Loss: 1.9847
# Epoch: 2/25... Step: 198... Loss: 1.9052... Val Loss: 1.9786
# Epoch: 2/25... Step: 200... Loss: 1.8679... Val Loss: 1.9818
# Epoch: 2/25... Step: 202... Loss: 1.8862... Val Loss: 1.9811
# Epoch: 2/25... Step: 204... Loss: 1.8986... Val Loss: 1.9717
# Epoch: 2/25... Step: 206... Loss: 1.8723... Val Loss: 1.9668
# Epoch: 2/25... Step: 208... Loss: 1.8637... Val Loss: 1.9695
# Epoch: 2/25... Step: 210... Loss: 1.8879... Val Loss: 1.9640
# Epoch: 2/25... Step: 212... Loss: 1.8944... Val Loss: 1.9614
# Epoch: 2/25... Step: 214... Loss: 1.8667... Val Loss: 1.9614
# Epoch: 2/25... Step: 216... Loss: 1.8588... Val Loss: 1.9635
# Epoch: 2/25... Step: 218... Loss: 1.8589... Val Loss: 1.9629
# Epoch: 2/25... Step: 220... Loss: 1.8492... Val Loss: 1.9575
# Epoch: 2/25... Step: 222... Loss: 1.8846... Val Loss: 1.9535
# Epoch: 2/25... Step: 224... Loss: 1.8610... Val Loss: 1.9495
# Epoch: 2/25... Step: 226... Loss: 1.8500... Val Loss: 1.9505
# Epoch: 2/25... Step: 228... Loss: 1.8486... Val Loss: 1.9415
# Epoch: 2/25... Step: 230... Loss: 1.8677... Val Loss: 1.9414
# Epoch: 2/25... Step: 232... Loss: 1.8480... Val Loss: 1.9371
# Epoch: 2/25... Step: 234... Loss: 1.8289... Val Loss: 1.9434
# Epoch: 2/25... Step: 236... Loss: 1.8567... Val Loss: 1.9366
# Epoch: 2/25... Step: 238... Loss: 1.8282... Val Loss: 1.9404
# Epoch: 2/25... Step: 240... Loss: 1.8618... Val Loss: 1.9353
# Epoch: 2/25... Step: 242... Loss: 1.8684... Val Loss: 1.9327
# Epoch: 2/25... Step: 244... Loss: 1.8334... Val Loss: 1.9238
# Epoch: 2/25... Step: 246... Loss: 1.8318... Val Loss: 1.9211
# Epoch: 2/25... Step: 248... Loss: 1.8284... Val Loss: 1.9253
# Epoch: 2/25... Step: 250... Loss: 1.8181... Val Loss: 1.9212
# Epoch: 2/25... Step: 252... Loss: 1.8201... Val Loss: 1.9173
# Epoch: 2/25... Step: 254... Loss: 1.8141... Val Loss: 1.9111
# Epoch: 2/25... Step: 256... Loss: 1.8074... Val Loss: 1.9126
# Epoch: 2/25... Step: 258... Loss: 1.8122... Val Loss: 1.9163
# Epoch: 2/25... Step: 260... Loss: 1.7885... Val Loss: 1.9105
# Epoch: 2/25... Step: 262... Loss: 1.7828... Val Loss: 1.9058
# Epoch: 2/25... Step: 264... Loss: 1.7743... Val Loss: 1.9043
# Epoch: 2/25... Step: 266... Loss: 1.8010... Val Loss: 1.9005
# Epoch: 2/25... Step: 268... Loss: 1.8233... Val Loss: 1.8975
# Epoch: 2/25... Step: 270... Loss: 1.8212... Val Loss: 1.8938
# Epoch: 2/25... Step: 272... Loss: 1.8371... Val Loss: 1.8921
# Epoch: 2/25... Step: 274... Loss: 1.8247... Val Loss: 1.8916
# Epoch: 2/25... Step: 276... Loss: 1.8039... Val Loss: 1.8918
# Epoch: 2/25... Step: 278... Loss: 1.8216... Val Loss: 1.8868
# Epoch: 3/25... Step: 280... Loss: 1.8026... Val Loss: 1.8881
# Epoch: 3/25... Step: 282... Loss: 1.8019... Val Loss: 1.8892
# Epoch: 3/25... Step: 284... Loss: 1.7735... Val Loss: 1.8841
# Epoch: 3/25... Step: 286... Loss: 1.8197... Val Loss: 1.8806
# Epoch: 3/25... Step: 288... Loss: 1.8076... Val Loss: 1.8791
# Epoch: 3/25... Step: 290... Loss: 1.8120... Val Loss: 1.8741
# Epoch: 3/25... Step: 292... Loss: 1.7814... Val Loss: 1.8737
# Epoch: 3/25... Step: 294... Loss: 1.7771... Val Loss: 1.8695
# Epoch: 3/25... Step: 296... Loss: 1.7857... Val Loss: 1.8657
# Epoch: 3/25... Step: 298... Loss: 1.8038... Val Loss: 1.8642
# Epoch: 3/25... Step: 300... Loss: 1.7744... Val Loss: 1.8601
# Epoch: 3/25... Step: 302... Loss: 1.7573... Val Loss: 1.8672
# Epoch: 3/25... Step: 304... Loss: 1.7556... Val Loss: 1.8583
# Epoch: 3/25... Step: 306... Loss: 1.7763... Val Loss: 1.8559
# Epoch: 3/25... Step: 308... Loss: 1.7828... Val Loss: 1.8540
# Epoch: 3/25... Step: 310... Loss: 1.7595... Val Loss: 1.8557
# Epoch: 3/25... Step: 312... Loss: 1.7601... Val Loss: 1.8617
# Epoch: 3/25... Step: 314... Loss: 1.7562... Val Loss: 1.8538
# Epoch: 3/25... Step: 316... Loss: 1.7866... Val Loss: 1.8491
# Epoch: 3/25... Step: 318... Loss: 1.7658... Val Loss: 1.8534
# Epoch: 3/25... Step: 320... Loss: 1.7296... Val Loss: 1.8521
# Epoch: 3/25... Step: 322... Loss: 1.7491... Val Loss: 1.8522
# Epoch: 3/25... Step: 324... Loss: 1.7465... Val Loss: 1.8448
# Epoch: 3/25... Step: 326... Loss: 1.7289... Val Loss: 1.8419
# Epoch: 3/25... Step: 328... Loss: 1.7798... Val Loss: 1.8399
# Epoch: 3/25... Step: 330... Loss: 1.7256... Val Loss: 1.8391
# Epoch: 3/25... Step: 332... Loss: 1.7330... Val Loss: 1.8349
# Epoch: 3/25... Step: 334... Loss: 1.7430... Val Loss: 1.8392
# Epoch: 3/25... Step: 336... Loss: 1.7260... Val Loss: 1.8348
# Epoch: 3/25... Step: 338... Loss: 1.7177... Val Loss: 1.8306
# Epoch: 3/25... Step: 340... Loss: 1.7810... Val Loss: 1.8345
# Epoch: 3/25... Step: 342... Loss: 1.7417... Val Loss: 1.8355
# Epoch: 3/25... Step: 344... Loss: 1.7272... Val Loss: 1.8280
# Epoch: 3/25... Step: 346... Loss: 1.7344... Val Loss: 1.8268
# Epoch: 3/25... Step: 348... Loss: 1.7206... Val Loss: 1.8249
# Epoch: 3/25... Step: 350... Loss: 1.7299... Val Loss: 1.8196
# Epoch: 3/25... Step: 352... Loss: 1.7485... Val Loss: 1.8211
# Epoch: 3/25... Step: 354... Loss: 1.6899... Val Loss: 1.8213
# Epoch: 3/25... Step: 356... Loss: 1.7455... Val Loss: 1.8264
# Epoch: 3/25... Step: 358... Loss: 1.7037... Val Loss: 1.8228
# Epoch: 3/25... Step: 360... Loss: 1.6839... Val Loss: 1.8195
# Epoch: 3/25... Step: 362... Loss: 1.7142... Val Loss: 1.8144
# Epoch: 3/25... Step: 364... Loss: 1.7205... Val Loss: 1.8146
# Epoch: 3/25... Step: 366... Loss: 1.6986... Val Loss: 1.8082
# Epoch: 3/25... Step: 368... Loss: 1.7165... Val Loss: 1.8111
# Epoch: 3/25... Step: 370... Loss: 1.7085... Val Loss: 1.8064
# Epoch: 3/25... Step: 372... Loss: 1.6917... Val Loss: 1.8097
# Epoch: 3/25... Step: 374... Loss: 1.6861... Val Loss: 1.8129
# Epoch: 3/25... Step: 376... Loss: 1.7065... Val Loss: 1.8084
# Epoch: 3/25... Step: 378... Loss: 1.7048... Val Loss: 1.8036
# Epoch: 3/25... Step: 380... Loss: 1.7144... Val Loss: 1.8038
# Epoch: 3/25... Step: 382... Loss: 1.6723... Val Loss: 1.8049
# Epoch: 3/25... Step: 384... Loss: 1.6806... Val Loss: 1.7981
# Epoch: 3/25... Step: 386... Loss: 1.6854... Val Loss: 1.7965
# Epoch: 3/25... Step: 388... Loss: 1.6807... Val Loss: 1.8014
# Epoch: 3/25... Step: 390... Loss: 1.6887... Val Loss: 1.7939
# Epoch: 3/25... Step: 392... Loss: 1.6951... Val Loss: 1.7934
# Epoch: 3/25... Step: 394... Loss: 1.6884... Val Loss: 1.7901
# Epoch: 3/25... Step: 396... Loss: 1.6845... Val Loss: 1.7862
# Epoch: 3/25... Step: 398... Loss: 1.6538... Val Loss: 1.7849
# Epoch: 3/25... Step: 400... Loss: 1.6530... Val Loss: 1.7867
# Epoch: 3/25... Step: 402... Loss: 1.6938... Val Loss: 1.7816
# Epoch: 3/25... Step: 404... Loss: 1.6952... Val Loss: 1.7847
# Epoch: 3/25... Step: 406... Loss: 1.6765... Val Loss: 1.7839
# Epoch: 3/25... Step: 408... Loss: 1.7007... Val Loss: 1.7838
# Epoch: 3/25... Step: 410... Loss: 1.6845... Val Loss: 1.7871
# Epoch: 3/25... Step: 412... Loss: 1.6702... Val Loss: 1.7780
# Epoch: 3/25... Step: 414... Loss: 1.7016... Val Loss: 1.7832
# Epoch: 3/25... Step: 416... Loss: 1.6874... Val Loss: 1.7802
# Epoch: 4/25... Step: 418... Loss: 1.7036... Val Loss: 1.7800
# Epoch: 4/25... Step: 420... Loss: 1.6851... Val Loss: 1.7808
# Epoch: 4/25... Step: 422... Loss: 1.6800... Val Loss: 1.7726
# Epoch: 4/25... Step: 424... Loss: 1.6723... Val Loss: 1.7684
# Epoch: 4/25... Step: 426... Loss: 1.6681... Val Loss: 1.7713
# Epoch: 4/25... Step: 428... Loss: 1.6875... Val Loss: 1.7650
# Epoch: 4/25... Step: 430... Loss: 1.6761... Val Loss: 1.7640
# Epoch: 4/25... Step: 432... Loss: 1.6648... Val Loss: 1.7656
# Epoch: 4/25... Step: 434... Loss: 1.6657... Val Loss: 1.7611
# Epoch: 4/25... Step: 436... Loss: 1.6587... Val Loss: 1.7579
# Epoch: 4/25... Step: 438... Loss: 1.6921... Val Loss: 1.7543
# Epoch: 4/25... Step: 440... Loss: 1.6697... Val Loss: 1.7538
# Epoch: 4/25... Step: 442... Loss: 1.6425... Val Loss: 1.7542
# Epoch: 4/25... Step: 444... Loss: 1.6464... Val Loss: 1.7506
# Epoch: 4/25... Step: 446... Loss: 1.6770... Val Loss: 1.7517
# Epoch: 4/25... Step: 448... Loss: 1.6908... Val Loss: 1.7534
# Epoch: 4/25... Step: 450... Loss: 1.6256... Val Loss: 1.7593
# Epoch: 4/25... Step: 452... Loss: 1.6663... Val Loss: 1.7505
# Epoch: 4/25... Step: 454... Loss: 1.6889... Val Loss: 1.7511
# Epoch: 4/25... Step: 456... Loss: 1.6547... Val Loss: 1.7470
# Epoch: 4/25... Step: 458... Loss: 1.6355... Val Loss: 1.7477
# Epoch: 4/25... Step: 460... Loss: 1.5980... Val Loss: 1.7482
# Epoch: 4/25... Step: 462... Loss: 1.6213... Val Loss: 1.7477
# Epoch: 4/25... Step: 464... Loss: 1.6409... Val Loss: 1.7459
# Epoch: 4/25... Step: 466... Loss: 1.6364... Val Loss: 1.7411
# Epoch: 4/25... Step: 468... Loss: 1.5958... Val Loss: 1.7390
# Epoch: 4/25... Step: 470... Loss: 1.6509... Val Loss: 1.7375
# Epoch: 4/25... Step: 472... Loss: 1.5977... Val Loss: 1.7445
# Epoch: 4/25... Step: 474... Loss: 1.6245... Val Loss: 1.7469
# Epoch: 4/25... Step: 476... Loss: 1.6485... Val Loss: 1.7381
# Epoch: 4/25... Step: 478... Loss: 1.5937... Val Loss: 1.7395
# Epoch: 4/25... Step: 480... Loss: 1.6326... Val Loss: 1.7357
# Epoch: 4/25... Step: 482... Loss: 1.6473... Val Loss: 1.7397
# Epoch: 4/25... Step: 484... Loss: 1.6369... Val Loss: 1.7291
# Epoch: 4/25... Step: 486... Loss: 1.6167... Val Loss: 1.7303
# Epoch: 4/25... Step: 488... Loss: 1.6294... Val Loss: 1.7295
# Epoch: 4/25... Step: 490... Loss: 1.6352... Val Loss: 1.7289
# Epoch: 4/25... Step: 492... Loss: 1.6066... Val Loss: 1.7293
# Epoch: 4/25... Step: 494... Loss: 1.6050... Val Loss: 1.7303
# Epoch: 4/25... Step: 496... Loss: 1.6093... Val Loss: 1.7326
# Epoch: 4/25... Step: 498... Loss: 1.6027... Val Loss: 1.7371
# Epoch: 4/25... Step: 500... Loss: 1.6323... Val Loss: 1.7259
# Epoch: 4/25... Step: 502... Loss: 1.6054... Val Loss: 1.7301
# Epoch: 4/25... Step: 504... Loss: 1.6041... Val Loss: 1.7236
# Epoch: 4/25... Step: 506... Loss: 1.6061... Val Loss: 1.7232
# Epoch: 4/25... Step: 508... Loss: 1.6191... Val Loss: 1.7233
# Epoch: 4/25... Step: 510... Loss: 1.6168... Val Loss: 1.7210
# Epoch: 4/25... Step: 512... Loss: 1.5885... Val Loss: 1.7213
# Epoch: 4/25... Step: 514... Loss: 1.6096... Val Loss: 1.7222
# Epoch: 4/25... Step: 516... Loss: 1.5848... Val Loss: 1.7154
# Epoch: 4/25... Step: 518... Loss: 1.6200... Val Loss: 1.7154
# Epoch: 4/25... Step: 520... Loss: 1.6185... Val Loss: 1.7147
# Epoch: 4/25... Step: 522... Loss: 1.6172... Val Loss: 1.7130
# Epoch: 4/25... Step: 524... Loss: 1.6024... Val Loss: 1.7091
# Epoch: 4/25... Step: 526... Loss: 1.5806... Val Loss: 1.7089
# Epoch: 4/25... Step: 528... Loss: 1.5771... Val Loss: 1.7074
# Epoch: 4/25... Step: 530... Loss: 1.5928... Val Loss: 1.7093
# Epoch: 4/25... Step: 532... Loss: 1.5841... Val Loss: 1.7056
# Epoch: 4/25... Step: 534... Loss: 1.5864... Val Loss: 1.7074
# Epoch: 4/25... Step: 536... Loss: 1.5766... Val Loss: 1.6994
# Epoch: 4/25... Step: 538... Loss: 1.5648... Val Loss: 1.7032
# Epoch: 4/25... Step: 540... Loss: 1.5606... Val Loss: 1.7127
# Epoch: 4/25... Step: 542... Loss: 1.5507... Val Loss: 1.6983
# Epoch: 4/25... Step: 544... Loss: 1.5816... Val Loss: 1.6971
# Epoch: 4/25... Step: 546... Loss: 1.6084... Val Loss: 1.7006
# Epoch: 4/25... Step: 548... Loss: 1.6106... Val Loss: 1.6986
# Epoch: 4/25... Step: 550... Loss: 1.6269... Val Loss: 1.6931
# Epoch: 4/25... Step: 552... Loss: 1.5876... Val Loss: 1.6997
# Epoch: 4/25... Step: 554... Loss: 1.5789... Val Loss: 1.6965
# Epoch: 4/25... Step: 556... Loss: 1.6027... Val Loss: 1.6979
# Epoch: 5/25... Step: 558... Loss: 1.5753... Val Loss: 1.6947
# Epoch: 5/25... Step: 560... Loss: 1.5698... Val Loss: 1.6973
# Epoch: 5/25... Step: 562... Loss: 1.5575... Val Loss: 1.6925
# Epoch: 5/25... Step: 564... Loss: 1.5935... Val Loss: 1.6921
# Epoch: 5/25... Step: 566... Loss: 1.6146... Val Loss: 1.6905
# Epoch: 5/25... Step: 568... Loss: 1.5930... Val Loss: 1.6853
# Epoch: 5/25... Step: 570... Loss: 1.5718... Val Loss: 1.6828
# Epoch: 5/25... Step: 572... Loss: 1.5682... Val Loss: 1.6844
# Epoch: 5/25... Step: 574... Loss: 1.5849... Val Loss: 1.6825
# Epoch: 5/25... Step: 576... Loss: 1.6048... Val Loss: 1.6843
# Epoch: 5/25... Step: 578... Loss: 1.5634... Val Loss: 1.6791
# Epoch: 5/25... Step: 580... Loss: 1.5539... Val Loss: 1.6899
# Epoch: 5/25... Step: 582... Loss: 1.5483... Val Loss: 1.6877
# Epoch: 5/25... Step: 584... Loss: 1.5626... Val Loss: 1.6782
# Epoch: 5/25... Step: 586... Loss: 1.5884... Val Loss: 1.6787
# Epoch: 5/25... Step: 588... Loss: 1.5720... Val Loss: 1.6801
# Epoch: 5/25... Step: 590... Loss: 1.5493... Val Loss: 1.6789
# Epoch: 5/25... Step: 592... Loss: 1.5542... Val Loss: 1.6761
# Epoch: 5/25... Step: 594... Loss: 1.5823... Val Loss: 1.6765
# Epoch: 5/25... Step: 596... Loss: 1.5666... Val Loss: 1.6749
# Epoch: 5/25... Step: 598... Loss: 1.5253... Val Loss: 1.6799
# Epoch: 5/25... Step: 600... Loss: 1.5426... Val Loss: 1.6831
# Epoch: 5/25... Step: 602... Loss: 1.5609... Val Loss: 1.6770
# Epoch: 5/25... Step: 604... Loss: 1.5449... Val Loss: 1.6776
# Epoch: 5/25... Step: 606... Loss: 1.5905... Val Loss: 1.6749
# Epoch: 5/25... Step: 608... Loss: 1.5419... Val Loss: 1.6691
# Epoch: 5/25... Step: 610... Loss: 1.5317... Val Loss: 1.6746
# Epoch: 5/25... Step: 612... Loss: 1.5637... Val Loss: 1.6751
# Epoch: 5/25... Step: 614... Loss: 1.5437... Val Loss: 1.6770
# Epoch: 5/25... Step: 616... Loss: 1.5399... Val Loss: 1.6706
# Epoch: 5/25... Step: 618... Loss: 1.5809... Val Loss: 1.6648
# Epoch: 5/25... Step: 620... Loss: 1.5468... Val Loss: 1.6644
# Epoch: 5/25... Step: 622... Loss: 1.5503... Val Loss: 1.6653
# Epoch: 5/25... Step: 624... Loss: 1.5454... Val Loss: 1.6641
# Epoch: 5/25... Step: 626... Loss: 1.5337... Val Loss: 1.6667
# Epoch: 5/25... Step: 628... Loss: 1.5395... Val Loss: 1.6657
# Epoch: 5/25... Step: 630... Loss: 1.5651... Val Loss: 1.6622
# Epoch: 5/25... Step: 632... Loss: 1.4993... Val Loss: 1.6593
# Epoch: 5/25... Step: 634... Loss: 1.5641... Val Loss: 1.6600
# Epoch: 5/25... Step: 636... Loss: 1.5221... Val Loss: 1.6607
# Epoch: 5/25... Step: 638... Loss: 1.5032... Val Loss: 1.6601
# Epoch: 5/25... Step: 640... Loss: 1.5277... Val Loss: 1.6542
# Epoch: 5/25... Step: 642... Loss: 1.5321... Val Loss: 1.6568
# Epoch: 5/25... Step: 644... Loss: 1.5199... Val Loss: 1.6531
# Epoch: 5/25... Step: 646... Loss: 1.5354... Val Loss: 1.6536
# Epoch: 5/25... Step: 648... Loss: 1.5318... Val Loss: 1.6561
# Epoch: 5/25... Step: 650... Loss: 1.5388... Val Loss: 1.6512
# Epoch: 5/25... Step: 652... Loss: 1.5112... Val Loss: 1.6538
# Epoch: 5/25... Step: 654... Loss: 1.5295... Val Loss: 1.6500
# Epoch: 5/25... Step: 656... Loss: 1.5254... Val Loss: 1.6524
# Epoch: 5/25... Step: 658... Loss: 1.5433... Val Loss: 1.6483
# Epoch: 5/25... Step: 660... Loss: 1.5134... Val Loss: 1.6528
# Epoch: 5/25... Step: 662... Loss: 1.5166... Val Loss: 1.6460
# Epoch: 5/25... Step: 664... Loss: 1.5173... Val Loss: 1.6473
# Epoch: 5/25... Step: 666... Loss: 1.5045... Val Loss: 1.6492
# Epoch: 5/25... Step: 668... Loss: 1.5107... Val Loss: 1.6602
# Epoch: 5/25... Step: 670... Loss: 1.5341... Val Loss: 1.6535
# Epoch: 5/25... Step: 672... Loss: 1.5291... Val Loss: 1.6432
# Epoch: 5/25... Step: 674... Loss: 1.5109... Val Loss: 1.6451
# Epoch: 5/25... Step: 676... Loss: 1.4910... Val Loss: 1.6515
# Epoch: 5/25... Step: 678... Loss: 1.4963... Val Loss: 1.6456
# Epoch: 5/25... Step: 680... Loss: 1.5359... Val Loss: 1.6372
# Epoch: 5/25... Step: 682... Loss: 1.5359... Val Loss: 1.6435
# Epoch: 5/25... Step: 684... Loss: 1.5111... Val Loss: 1.6342
# Epoch: 5/25... Step: 686... Loss: 1.5419... Val Loss: 1.6355
# Epoch: 5/25... Step: 688... Loss: 1.5204... Val Loss: 1.6394
# Epoch: 5/25... Step: 690... Loss: 1.5086... Val Loss: 1.6378
# Epoch: 5/25... Step: 692... Loss: 1.5262... Val Loss: 1.6372
# Epoch: 5/25... Step: 694... Loss: 1.5140... Val Loss: 1.6311
# Epoch: 6/25... Step: 696... Loss: 1.5456... Val Loss: 1.6348
# Epoch: 6/25... Step: 698... Loss: 1.5278... Val Loss: 1.6324
# Epoch: 6/25... Step: 700... Loss: 1.5132... Val Loss: 1.6323
# Epoch: 6/25... Step: 702... Loss: 1.4894... Val Loss: 1.6318
# Epoch: 6/25... Step: 704... Loss: 1.5155... Val Loss: 1.6298
# Epoch: 6/25... Step: 706... Loss: 1.5301... Val Loss: 1.6267
# Epoch: 6/25... Step: 708... Loss: 1.5109... Val Loss: 1.6295
# Epoch: 6/25... Step: 710... Loss: 1.5083... Val Loss: 1.6218
# Epoch: 6/25... Step: 712... Loss: 1.4952... Val Loss: 1.6299
# Epoch: 6/25... Step: 714... Loss: 1.5075... Val Loss: 1.6314
# Epoch: 6/25... Step: 716... Loss: 1.5320... Val Loss: 1.6248
# Epoch: 6/25... Step: 718... Loss: 1.5139... Val Loss: 1.6243
# Epoch: 6/25... Step: 720... Loss: 1.5008... Val Loss: 1.6254
# Epoch: 6/25... Step: 722... Loss: 1.4959... Val Loss: 1.6301
# Epoch: 6/25... Step: 724... Loss: 1.5187... Val Loss: 1.6261
# Epoch: 6/25... Step: 726... Loss: 1.5422... Val Loss: 1.6192
# Epoch: 6/25... Step: 728... Loss: 1.4703... Val Loss: 1.6192
# Epoch: 6/25... Step: 730... Loss: 1.5036... Val Loss: 1.6237
# Epoch: 6/25... Step: 732... Loss: 1.5210... Val Loss: 1.6187
# Epoch: 6/25... Step: 734... Loss: 1.5056... Val Loss: 1.6199
# Epoch: 6/25... Step: 736... Loss: 1.4790... Val Loss: 1.6174
# Epoch: 6/25... Step: 738... Loss: 1.4475... Val Loss: 1.6240
# Epoch: 6/25... Step: 740... Loss: 1.4716... Val Loss: 1.6232
# Epoch: 6/25... Step: 742... Loss: 1.4944... Val Loss: 1.6194
# Epoch: 6/25... Step: 744... Loss: 1.4907... Val Loss: 1.6213
# Epoch: 6/25... Step: 746... Loss: 1.4506... Val Loss: 1.6170
# Epoch: 6/25... Step: 748... Loss: 1.5018... Val Loss: 1.6165
# Epoch: 6/25... Step: 750... Loss: 1.4536... Val Loss: 1.6174
# Epoch: 6/25... Step: 752... Loss: 1.4823... Val Loss: 1.6241
# Epoch: 6/25... Step: 754... Loss: 1.4957... Val Loss: 1.6146
# Epoch: 6/25... Step: 756... Loss: 1.4567... Val Loss: 1.6122
# Epoch: 6/25... Step: 758... Loss: 1.5003... Val Loss: 1.6118
# Epoch: 6/25... Step: 760... Loss: 1.5028... Val Loss: 1.6127
# Epoch: 6/25... Step: 762... Loss: 1.4803... Val Loss: 1.6114
# Epoch: 6/25... Step: 764... Loss: 1.4681... Val Loss: 1.6131
# Epoch: 6/25... Step: 766... Loss: 1.4847... Val Loss: 1.6118
# Epoch: 6/25... Step: 768... Loss: 1.4913... Val Loss: 1.6095
# Epoch: 6/25... Step: 770... Loss: 1.4806... Val Loss: 1.6112
# Epoch: 6/25... Step: 772... Loss: 1.4665... Val Loss: 1.6119
# Epoch: 6/25... Step: 774... Loss: 1.4677... Val Loss: 1.6082
# Epoch: 6/25... Step: 776... Loss: 1.4617... Val Loss: 1.6041
# Epoch: 6/25... Step: 778... Loss: 1.4973... Val Loss: 1.6073
# Epoch: 6/25... Step: 780... Loss: 1.4660... Val Loss: 1.6012
# Epoch: 6/25... Step: 782... Loss: 1.4701... Val Loss: 1.5981
# Epoch: 6/25... Step: 784... Loss: 1.4589... Val Loss: 1.6016
# Epoch: 6/25... Step: 786... Loss: 1.4618... Val Loss: 1.5955
# Epoch: 6/25... Step: 788... Loss: 1.4788... Val Loss: 1.5979
# Epoch: 6/25... Step: 790... Loss: 1.4579... Val Loss: 1.5937
# Epoch: 6/25... Step: 792... Loss: 1.4662... Val Loss: 1.6003
# Epoch: 6/25... Step: 794... Loss: 1.4459... Val Loss: 1.5943
# Epoch: 6/25... Step: 796... Loss: 1.4789... Val Loss: 1.5970
# Epoch: 6/25... Step: 798... Loss: 1.4820... Val Loss: 1.6014
# Epoch: 6/25... Step: 800... Loss: 1.4825... Val Loss: 1.6035
# Epoch: 6/25... Step: 802... Loss: 1.4642... Val Loss: 1.6012
# Epoch: 6/25... Step: 804... Loss: 1.4539... Val Loss: 1.6001
# Epoch: 6/25... Step: 806... Loss: 1.4534... Val Loss: 1.5978
# Epoch: 6/25... Step: 808... Loss: 1.4585... Val Loss: 1.5983
# Epoch: 6/25... Step: 810... Loss: 1.4512... Val Loss: 1.5994
# Epoch: 6/25... Step: 812... Loss: 1.4586... Val Loss: 1.5897
# Epoch: 6/25... Step: 814... Loss: 1.4430... Val Loss: 1.5942
# Epoch: 6/25... Step: 816... Loss: 1.4321... Val Loss: 1.5977
# Epoch: 6/25... Step: 818... Loss: 1.4328... Val Loss: 1.5924
# Epoch: 6/25... Step: 820... Loss: 1.4110... Val Loss: 1.5895
# Epoch: 6/25... Step: 822... Loss: 1.4561... Val Loss: 1.5853
# Epoch: 6/25... Step: 824... Loss: 1.4816... Val Loss: 1.5865
# Epoch: 6/25... Step: 826... Loss: 1.4834... Val Loss: 1.5855
# Epoch: 6/25... Step: 828... Loss: 1.4951... Val Loss: 1.5866
# Epoch: 6/25... Step: 830... Loss: 1.4610... Val Loss: 1.5900
# Epoch: 6/25... Step: 832... Loss: 1.4549... Val Loss: 1.5865
# Epoch: 6/25... Step: 834... Loss: 1.4936... Val Loss: 1.5823
# Epoch: 7/25... Step: 836... Loss: 1.4459... Val Loss: 1.5902
# Epoch: 7/25... Step: 838... Loss: 1.4565... Val Loss: 1.5882
# Epoch: 7/25... Step: 840... Loss: 1.4368... Val Loss: 1.5916
# Epoch: 7/25... Step: 842... Loss: 1.4630... Val Loss: 1.5922
# Epoch: 7/25... Step: 844... Loss: 1.4947... Val Loss: 1.5831
# Epoch: 7/25... Step: 846... Loss: 1.4631... Val Loss: 1.5857
# Epoch: 7/25... Step: 848... Loss: 1.4611... Val Loss: 1.5804
# Epoch: 7/25... Step: 850... Loss: 1.4442... Val Loss: 1.5824
# Epoch: 7/25... Step: 852... Loss: 1.4618... Val Loss: 1.5817
# Epoch: 7/25... Step: 854... Loss: 1.4999... Val Loss: 1.5767
# Epoch: 7/25... Step: 856... Loss: 1.4373... Val Loss: 1.5756
# Epoch: 7/25... Step: 858... Loss: 1.4476... Val Loss: 1.5797
# Epoch: 7/25... Step: 860... Loss: 1.4269... Val Loss: 1.5829
# Epoch: 7/25... Step: 862... Loss: 1.4557... Val Loss: 1.5815
# Epoch: 7/25... Step: 864... Loss: 1.4806... Val Loss: 1.5774
# Epoch: 7/25... Step: 866... Loss: 1.4519... Val Loss: 1.5752
# Epoch: 7/25... Step: 868... Loss: 1.4358... Val Loss: 1.5794
# Epoch: 7/25... Step: 870... Loss: 1.4425... Val Loss: 1.5768
# Epoch: 7/25... Step: 872... Loss: 1.4752... Val Loss: 1.5783
# Epoch: 7/25... Step: 874... Loss: 1.4516... Val Loss: 1.5761
# Epoch: 7/25... Step: 876... Loss: 1.4167... Val Loss: 1.5764
# Epoch: 7/25... Step: 878... Loss: 1.4305... Val Loss: 1.5812
# Epoch: 7/25... Step: 880... Loss: 1.4402... Val Loss: 1.5798
# Epoch: 7/25... Step: 882... Loss: 1.4282... Val Loss: 1.5749
# Epoch: 7/25... Step: 884... Loss: 1.4697... Val Loss: 1.5735
# Epoch: 7/25... Step: 886... Loss: 1.4229... Val Loss: 1.5745
# Epoch: 7/25... Step: 888... Loss: 1.4158... Val Loss: 1.5711
# Epoch: 7/25... Step: 890... Loss: 1.4477... Val Loss: 1.5735
# Epoch: 7/25... Step: 892... Loss: 1.4453... Val Loss: 1.5702
# Epoch: 7/25... Step: 894... Loss: 1.4031... Val Loss: 1.5695
# Epoch: 7/25... Step: 896... Loss: 1.4608... Val Loss: 1.5676
# Epoch: 7/25... Step: 898... Loss: 1.4391... Val Loss: 1.5654
# Epoch: 7/25... Step: 900... Loss: 1.4399... Val Loss: 1.5736
# Epoch: 7/25... Step: 902... Loss: 1.4339... Val Loss: 1.5681
# Epoch: 7/25... Step: 904... Loss: 1.4269... Val Loss: 1.5709
# Epoch: 7/25... Step: 906... Loss: 1.4376... Val Loss: 1.5728
# Epoch: 7/25... Step: 908... Loss: 1.4404... Val Loss: 1.5704
# Epoch: 7/25... Step: 910... Loss: 1.4026... Val Loss: 1.5679
# Epoch: 7/25... Step: 912... Loss: 1.4552... Val Loss: 1.5691
# Epoch: 7/25... Step: 914... Loss: 1.4203... Val Loss: 1.5642
# Epoch: 7/25... Step: 916... Loss: 1.3831... Val Loss: 1.5670
# Epoch: 7/25... Step: 918... Loss: 1.4200... Val Loss: 1.5605
# Epoch: 7/25... Step: 920... Loss: 1.4308... Val Loss: 1.5631
# Epoch: 7/25... Step: 922... Loss: 1.4152... Val Loss: 1.5581
# Epoch: 7/25... Step: 924... Loss: 1.4279... Val Loss: 1.5616
# Epoch: 7/25... Step: 926... Loss: 1.4322... Val Loss: 1.5589
# Epoch: 7/25... Step: 928... Loss: 1.4308... Val Loss: 1.5592
# Epoch: 7/25... Step: 930... Loss: 1.4118... Val Loss: 1.5573
# Epoch: 7/25... Step: 932... Loss: 1.4201... Val Loss: 1.5626
# Epoch: 7/25... Step: 934... Loss: 1.4189... Val Loss: 1.5587
# Epoch: 7/25... Step: 936... Loss: 1.4440... Val Loss: 1.5569
# Epoch: 7/25... Step: 938... Loss: 1.4105... Val Loss: 1.5578
# Epoch: 7/25... Step: 940... Loss: 1.4056... Val Loss: 1.5645
# Epoch: 7/25... Step: 942... Loss: 1.4301... Val Loss: 1.5608
# Epoch: 7/25... Step: 944... Loss: 1.4055... Val Loss: 1.5688
# Epoch: 7/25... Step: 946... Loss: 1.4242... Val Loss: 1.5630
# Epoch: 7/25... Step: 948... Loss: 1.4322... Val Loss: 1.5689
# Epoch: 7/25... Step: 950... Loss: 1.4309... Val Loss: 1.5672
# Epoch: 7/25... Step: 952... Loss: 1.4142... Val Loss: 1.5575
# Epoch: 7/25... Step: 954... Loss: 1.3953... Val Loss: 1.5665
# Epoch: 7/25... Step: 956... Loss: 1.4053... Val Loss: 1.5647
# Epoch: 7/25... Step: 958... Loss: 1.4421... Val Loss: 1.5637
# Epoch: 7/25... Step: 960... Loss: 1.4506... Val Loss: 1.5555
# Epoch: 7/25... Step: 962... Loss: 1.4060... Val Loss: 1.5556
# Epoch: 7/25... Step: 964... Loss: 1.4327... Val Loss: 1.5585
# Epoch: 7/25... Step: 966... Loss: 1.4217... Val Loss: 1.5560
# Epoch: 7/25... Step: 968... Loss: 1.4185... Val Loss: 1.5575
# Epoch: 7/25... Step: 970... Loss: 1.4317... Val Loss: 1.5597
# Epoch: 7/25... Step: 972... Loss: 1.4202... Val Loss: 1.5550
# Epoch: 8/25... Step: 974... Loss: 1.4576... Val Loss: 1.5546
# Epoch: 8/25... Step: 976... Loss: 1.4252... Val Loss: 1.5568
# Epoch: 8/25... Step: 978... Loss: 1.4265... Val Loss: 1.5534
# Epoch: 8/25... Step: 980... Loss: 1.4023... Val Loss: 1.5586
# Epoch: 8/25... Step: 982... Loss: 1.4203... Val Loss: 1.5503
# Epoch: 8/25... Step: 984... Loss: 1.4297... Val Loss: 1.5572
# Epoch: 8/25... Step: 986... Loss: 1.4129... Val Loss: 1.5545
# Epoch: 8/25... Step: 988... Loss: 1.4145... Val Loss: 1.5574
# Epoch: 8/25... Step: 990... Loss: 1.4140... Val Loss: 1.5441
# Epoch: 8/25... Step: 992... Loss: 1.4194... Val Loss: 1.5508
# Epoch: 8/25... Step: 994... Loss: 1.4411... Val Loss: 1.5479
# Epoch: 8/25... Step: 996... Loss: 1.4272... Val Loss: 1.5463
# Epoch: 8/25... Step: 998... Loss: 1.4059... Val Loss: 1.5433
# Epoch: 8/25... Step: 1000... Loss: 1.4082... Val Loss: 1.5443
# Epoch: 8/25... Step: 1002... Loss: 1.4243... Val Loss: 1.5436
# Epoch: 8/25... Step: 1004... Loss: 1.4450... Val Loss: 1.5449
# Epoch: 8/25... Step: 1006... Loss: 1.3731... Val Loss: 1.5458
# Epoch: 8/25... Step: 1008... Loss: 1.4204... Val Loss: 1.5455
# Epoch: 8/25... Step: 1010... Loss: 1.4303... Val Loss: 1.5438
# Epoch: 8/25... Step: 1012... Loss: 1.4067... Val Loss: 1.5430
# Epoch: 8/25... Step: 1014... Loss: 1.3861... Val Loss: 1.5394
# Epoch: 8/25... Step: 1016... Loss: 1.3580... Val Loss: 1.5466
# Epoch: 8/25... Step: 1018... Loss: 1.3818... Val Loss: 1.5505
# Epoch: 8/25... Step: 1020... Loss: 1.4141... Val Loss: 1.5458
# Epoch: 8/25... Step: 1022... Loss: 1.4059... Val Loss: 1.5476
# Epoch: 8/25... Step: 1024... Loss: 1.3720... Val Loss: 1.5486
# Epoch: 8/25... Step: 1026... Loss: 1.4166... Val Loss: 1.5446
# Epoch: 8/25... Step: 1028... Loss: 1.3887... Val Loss: 1.5431
# Epoch: 8/25... Step: 1030... Loss: 1.3990... Val Loss: 1.5426
# Epoch: 8/25... Step: 1032... Loss: 1.4234... Val Loss: 1.5471
# Epoch: 8/25... Step: 1034... Loss: 1.3808... Val Loss: 1.5514
# Epoch: 8/25... Step: 1036... Loss: 1.4223... Val Loss: 1.5434
# Epoch: 8/25... Step: 1038... Loss: 1.4256... Val Loss: 1.5458
# Epoch: 8/25... Step: 1040... Loss: 1.4100... Val Loss: 1.5445
# Epoch: 8/25... Step: 1042... Loss: 1.3900... Val Loss: 1.5420
# Epoch: 8/25... Step: 1044... Loss: 1.3975... Val Loss: 1.5448
# Epoch: 8/25... Step: 1046... Loss: 1.4127... Val Loss: 1.5453
# Epoch: 8/25... Step: 1048... Loss: 1.3873... Val Loss: 1.5446
# Epoch: 8/25... Step: 1050... Loss: 1.3919... Val Loss: 1.5383
# Epoch: 8/25... Step: 1052... Loss: 1.3898... Val Loss: 1.5385
# Epoch: 8/25... Step: 1054... Loss: 1.3872... Val Loss: 1.5386
# Epoch: 8/25... Step: 1056... Loss: 1.4198... Val Loss: 1.5389
# Epoch: 8/25... Step: 1058... Loss: 1.3868... Val Loss: 1.5371
# Epoch: 8/25... Step: 1060... Loss: 1.3880... Val Loss: 1.5402
# Epoch: 8/25... Step: 1062... Loss: 1.3708... Val Loss: 1.5365
# Epoch: 8/25... Step: 1064... Loss: 1.3848... Val Loss: 1.5375
# Epoch: 8/25... Step: 1066... Loss: 1.3982... Val Loss: 1.5324
# Epoch: 8/25... Step: 1068... Loss: 1.3797... Val Loss: 1.5342
# Epoch: 8/25... Step: 1070... Loss: 1.3909... Val Loss: 1.5379
# Epoch: 8/25... Step: 1072... Loss: 1.3655... Val Loss: 1.5350
# Epoch: 8/25... Step: 1074... Loss: 1.4041... Val Loss: 1.5324
# Epoch: 8/25... Step: 1076... Loss: 1.4013... Val Loss: 1.5340
# Epoch: 8/25... Step: 1078... Loss: 1.4082... Val Loss: 1.5372
# Epoch: 8/25... Step: 1080... Loss: 1.3870... Val Loss: 1.5375
# Epoch: 8/25... Step: 1082... Loss: 1.3679... Val Loss: 1.5343
# Epoch: 8/25... Step: 1084... Loss: 1.3713... Val Loss: 1.5324
# Epoch: 8/25... Step: 1086... Loss: 1.3980... Val Loss: 1.5322
# Epoch: 8/25... Step: 1088... Loss: 1.3760... Val Loss: 1.5331
# Epoch: 8/25... Step: 1090... Loss: 1.3753... Val Loss: 1.5317
# Epoch: 8/25... Step: 1092... Loss: 1.3735... Val Loss: 1.5297
# Epoch: 8/25... Step: 1094... Loss: 1.3499... Val Loss: 1.5288
# Epoch: 8/25... Step: 1096... Loss: 1.3423... Val Loss: 1.5315
# Epoch: 8/25... Step: 1098... Loss: 1.3347... Val Loss: 1.5270
# Epoch: 8/25... Step: 1100... Loss: 1.3788... Val Loss: 1.5267
# Epoch: 8/25... Step: 1102... Loss: 1.4009... Val Loss: 1.5262
# Epoch: 8/25... Step: 1104... Loss: 1.4097... Val Loss: 1.5246
# Epoch: 8/25... Step: 1106... Loss: 1.4105... Val Loss: 1.5271
# Epoch: 8/25... Step: 1108... Loss: 1.3882... Val Loss: 1.5284
# Epoch: 8/25... Step: 1110... Loss: 1.3691... Val Loss: 1.5305
# Epoch: 8/25... Step: 1112... Loss: 1.4053... Val Loss: 1.5305
# Epoch: 9/25... Step: 1114... Loss: 1.3842... Val Loss: 1.5274
# Epoch: 9/25... Step: 1116... Loss: 1.3858... Val Loss: 1.5356
# Epoch: 9/25... Step: 1118... Loss: 1.3638... Val Loss: 1.5291
# Epoch: 9/25... Step: 1120... Loss: 1.3900... Val Loss: 1.5273
# Epoch: 9/25... Step: 1122... Loss: 1.4104... Val Loss: 1.5274
# Epoch: 9/25... Step: 1124... Loss: 1.3877... Val Loss: 1.5190
# Epoch: 9/25... Step: 1126... Loss: 1.3727... Val Loss: 1.5221
# Epoch: 9/25... Step: 1128... Loss: 1.3713... Val Loss: 1.5196
# Epoch: 9/25... Step: 1130... Loss: 1.3839... Val Loss: 1.5235
# Epoch: 9/25... Step: 1132... Loss: 1.4198... Val Loss: 1.5216
# Epoch: 9/25... Step: 1134... Loss: 1.3606... Val Loss: 1.5192
# Epoch: 9/25... Step: 1136... Loss: 1.3714... Val Loss: 1.5214
# Epoch: 9/25... Step: 1138... Loss: 1.3554... Val Loss: 1.5251
# Epoch: 9/25... Step: 1140... Loss: 1.3901... Val Loss: 1.5296
# Epoch: 9/25... Step: 1142... Loss: 1.4189... Val Loss: 1.5225
# Epoch: 9/25... Step: 1144... Loss: 1.3712... Val Loss: 1.5241
# Epoch: 9/25... Step: 1146... Loss: 1.3695... Val Loss: 1.5210
# Epoch: 9/25... Step: 1148... Loss: 1.3617... Val Loss: 1.5239
# Epoch: 9/25... Step: 1150... Loss: 1.3973... Val Loss: 1.5205
# Epoch: 9/25... Step: 1152... Loss: 1.3728... Val Loss: 1.5242
# Epoch: 9/25... Step: 1154... Loss: 1.3456... Val Loss: 1.5197
# Epoch: 9/25... Step: 1156... Loss: 1.3534... Val Loss: 1.5243
# Epoch: 9/25... Step: 1158... Loss: 1.3759... Val Loss: 1.5242
# Epoch: 9/25... Step: 1160... Loss: 1.3679... Val Loss: 1.5222
# Epoch: 9/25... Step: 1162... Loss: 1.3974... Val Loss: 1.5200
# Epoch: 9/25... Step: 1164... Loss: 1.3512... Val Loss: 1.5226
# Epoch: 9/25... Step: 1166... Loss: 1.3441... Val Loss: 1.5189
# Epoch: 9/25... Step: 1168... Loss: 1.3763... Val Loss: 1.5183
# Epoch: 9/25... Step: 1170... Loss: 1.3706... Val Loss: 1.5214
# Epoch: 9/25... Step: 1172... Loss: 1.3360... Val Loss: 1.5188
# Epoch: 9/25... Step: 1174... Loss: 1.3920... Val Loss: 1.5130
# Epoch: 9/25... Step: 1176... Loss: 1.3694... Val Loss: 1.5080
# Epoch: 9/25... Step: 1178... Loss: 1.3700... Val Loss: 1.5142
# Epoch: 9/25... Step: 1180... Loss: 1.3627... Val Loss: 1.5141
# Epoch: 9/25... Step: 1182... Loss: 1.3466... Val Loss: 1.5160
# Epoch: 9/25... Step: 1184... Loss: 1.3670... Val Loss: 1.5164
# Epoch: 9/25... Step: 1186... Loss: 1.3848... Val Loss: 1.5142
# Epoch: 9/25... Step: 1188... Loss: 1.3435... Val Loss: 1.5138
# Epoch: 9/25... Step: 1190... Loss: 1.3837... Val Loss: 1.5117
# Epoch: 9/25... Step: 1192... Loss: 1.3484... Val Loss: 1.5149
# Epoch: 9/25... Step: 1194... Loss: 1.3232... Val Loss: 1.5165
# Epoch: 9/25... Step: 1196... Loss: 1.3556... Val Loss: 1.5124
# Epoch: 9/25... Step: 1198... Loss: 1.3619... Val Loss: 1.5096
# Epoch: 9/25... Step: 1200... Loss: 1.3505... Val Loss: 1.5085
# Epoch: 9/25... Step: 1202... Loss: 1.3666... Val Loss: 1.5069
# Epoch: 9/25... Step: 1204... Loss: 1.3518... Val Loss: 1.5073
# Epoch: 9/25... Step: 1206... Loss: 1.3593... Val Loss: 1.5079
# Epoch: 9/25... Step: 1208... Loss: 1.3393... Val Loss: 1.5097
# Epoch: 9/25... Step: 1210... Loss: 1.3504... Val Loss: 1.5092
# Epoch: 9/25... Step: 1212... Loss: 1.3630... Val Loss: 1.5089
# Epoch: 9/25... Step: 1214... Loss: 1.3915... Val Loss: 1.5048
# Epoch: 9/25... Step: 1216... Loss: 1.3452... Val Loss: 1.5069
# Epoch: 9/25... Step: 1218... Loss: 1.3435... Val Loss: 1.5145
# Epoch: 9/25... Step: 1220... Loss: 1.3597... Val Loss: 1.5098
# Epoch: 9/25... Step: 1222... Loss: 1.3501... Val Loss: 1.5117
# Epoch: 9/25... Step: 1224... Loss: 1.3481... Val Loss: 1.5103
# Epoch: 9/25... Step: 1226... Loss: 1.3575... Val Loss: 1.5135
# Epoch: 9/25... Step: 1228... Loss: 1.3659... Val Loss: 1.5106
# Epoch: 9/25... Step: 1230... Loss: 1.3412... Val Loss: 1.5022
# Epoch: 9/25... Step: 1232... Loss: 1.3399... Val Loss: 1.5030
# Epoch: 9/25... Step: 1234... Loss: 1.3374... Val Loss: 1.5114
# Epoch: 9/25... Step: 1236... Loss: 1.3779... Val Loss: 1.5073
# Epoch: 9/25... Step: 1238... Loss: 1.3742... Val Loss: 1.5060
# Epoch: 9/25... Step: 1240... Loss: 1.3406... Val Loss: 1.5065
# Epoch: 9/25... Step: 1242... Loss: 1.3600... Val Loss: 1.5068
# Epoch: 9/25... Step: 1244... Loss: 1.3493... Val Loss: 1.5065
# Epoch: 9/25... Step: 1246... Loss: 1.3656... Val Loss: 1.5061
# Epoch: 9/25... Step: 1248... Loss: 1.3713... Val Loss: 1.5071
# Epoch: 9/25... Step: 1250... Loss: 1.3599... Val Loss: 1.5074
# Epoch: 10/25... Step: 1252... Loss: 1.4040... Val Loss: 1.5028
# Epoch: 10/25... Step: 1254... Loss: 1.3687... Val Loss: 1.5079
# Epoch: 10/25... Step: 1256... Loss: 1.3602... Val Loss: 1.5066
# Epoch: 10/25... Step: 1258... Loss: 1.3402... Val Loss: 1.5062
# Epoch: 10/25... Step: 1260... Loss: 1.3602... Val Loss: 1.5049
# Epoch: 10/25... Step: 1262... Loss: 1.3644... Val Loss: 1.5066
# Epoch: 10/25... Step: 1264... Loss: 1.3418... Val Loss: 1.4949
# Epoch: 10/25... Step: 1266... Loss: 1.3473... Val Loss: 1.4996
# Epoch: 10/25... Step: 1268... Loss: 1.3358... Val Loss: 1.4950
# Epoch: 10/25... Step: 1270... Loss: 1.3551... Val Loss: 1.5009
# Epoch: 10/25... Step: 1272... Loss: 1.3807... Val Loss: 1.4948
# Epoch: 10/25... Step: 1274... Loss: 1.3720... Val Loss: 1.5033
# Epoch: 10/25... Step: 1276... Loss: 1.3485... Val Loss: 1.4986
# Epoch: 10/25... Step: 1278... Loss: 1.3434... Val Loss: 1.5061
# Epoch: 10/25... Step: 1280... Loss: 1.3693... Val Loss: 1.5040
# Epoch: 10/25... Step: 1282... Loss: 1.3861... Val Loss: 1.5000
# Epoch: 10/25... Step: 1284... Loss: 1.3129... Val Loss: 1.5081
# Epoch: 10/25... Step: 1286... Loss: 1.3587... Val Loss: 1.5019
# Epoch: 10/25... Step: 1288... Loss: 1.3782... Val Loss: 1.5037
# Epoch: 10/25... Step: 1290... Loss: 1.3544... Val Loss: 1.5008
# Epoch: 10/25... Step: 1292... Loss: 1.3351... Val Loss: 1.4991
# Epoch: 10/25... Step: 1294... Loss: 1.2914... Val Loss: 1.5003
# Epoch: 10/25... Step: 1296... Loss: 1.3219... Val Loss: 1.5029
# Epoch: 10/25... Step: 1298... Loss: 1.3588... Val Loss: 1.5014
# Epoch: 10/25... Step: 1300... Loss: 1.3519... Val Loss: 1.4958
# Epoch: 10/25... Step: 1302... Loss: 1.3261... Val Loss: 1.4983
# Epoch: 10/25... Step: 1304... Loss: 1.3484... Val Loss: 1.4961
# Epoch: 10/25... Step: 1306... Loss: 1.3298... Val Loss: 1.4954
# Epoch: 10/25... Step: 1308... Loss: 1.3386... Val Loss: 1.4947
# Epoch: 10/25... Step: 1310... Loss: 1.3545... Val Loss: 1.4970
# Epoch: 10/25... Step: 1312... Loss: 1.3077... Val Loss: 1.4967
# Epoch: 10/25... Step: 1314... Loss: 1.3498... Val Loss: 1.4910
# Epoch: 10/25... Step: 1316... Loss: 1.3634... Val Loss: 1.4908
# Epoch: 10/25... Step: 1318... Loss: 1.3457... Val Loss: 1.4977
# Epoch: 10/25... Step: 1320... Loss: 1.3251... Val Loss: 1.4955
# Epoch: 10/25... Step: 1322... Loss: 1.3293... Val Loss: 1.4965
# Epoch: 10/25... Step: 1324... Loss: 1.3493... Val Loss: 1.4964
# Epoch: 10/25... Step: 1326... Loss: 1.3442... Val Loss: 1.4949
# Epoch: 10/25... Step: 1328... Loss: 1.3328... Val Loss: 1.4904
# Epoch: 10/25... Step: 1330... Loss: 1.3227... Val Loss: 1.4942
# Epoch: 10/25... Step: 1332... Loss: 1.3313... Val Loss: 1.4951
# Epoch: 10/25... Step: 1334... Loss: 1.3604... Val Loss: 1.4928
# Epoch: 10/25... Step: 1336... Loss: 1.3328... Val Loss: 1.4935
# Epoch: 10/25... Step: 1338... Loss: 1.3215... Val Loss: 1.4937
# Epoch: 10/25... Step: 1340... Loss: 1.3140... Val Loss: 1.4939
# Epoch: 10/25... Step: 1342... Loss: 1.3222... Val Loss: 1.4884
# Epoch: 10/25... Step: 1344... Loss: 1.3396... Val Loss: 1.4909
# Epoch: 10/25... Step: 1346... Loss: 1.3135... Val Loss: 1.4844
# Epoch: 10/25... Step: 1348... Loss: 1.3293... Val Loss: 1.4883
# Epoch: 10/25... Step: 1350... Loss: 1.3094... Val Loss: 1.4928
# Epoch: 10/25... Step: 1352... Loss: 1.3511... Val Loss: 1.4867
# Epoch: 10/25... Step: 1354... Loss: 1.3394... Val Loss: 1.4810
# Epoch: 10/25... Step: 1356... Loss: 1.3421... Val Loss: 1.4912
# Epoch: 10/25... Step: 1358... Loss: 1.3307... Val Loss: 1.4913
# Epoch: 10/25... Step: 1360... Loss: 1.3155... Val Loss: 1.4895
# Epoch: 10/25... Step: 1362... Loss: 1.3231... Val Loss: 1.4930
# Epoch: 10/25... Step: 1364... Loss: 1.3459... Val Loss: 1.4889
# Epoch: 10/25... Step: 1366... Loss: 1.3191... Val Loss: 1.4880
# Epoch: 10/25... Step: 1368... Loss: 1.3167... Val Loss: 1.4828
# Epoch: 10/25... Step: 1370... Loss: 1.3127... Val Loss: 1.4840
# Epoch: 10/25... Step: 1372... Loss: 1.2884... Val Loss: 1.4862
# Epoch: 10/25... Step: 1374... Loss: 1.3089... Val Loss: 1.4873
# Epoch: 10/25... Step: 1376... Loss: 1.2850... Val Loss: 1.4840
# Epoch: 10/25... Step: 1378... Loss: 1.3143... Val Loss: 1.4817
# Epoch: 10/25... Step: 1380... Loss: 1.3450... Val Loss: 1.4825
# Epoch: 10/25... Step: 1382... Loss: 1.3543... Val Loss: 1.4819
# Epoch: 10/25... Step: 1384... Loss: 1.3587... Val Loss: 1.4833
# Epoch: 10/25... Step: 1386... Loss: 1.3320... Val Loss: 1.4884
# Epoch: 10/25... Step: 1388... Loss: 1.3245... Val Loss: 1.4866
# Epoch: 10/25... Step: 1390... Loss: 1.3637... Val Loss: 1.4852
# Epoch: 11/25... Step: 1392... Loss: 1.3222... Val Loss: 1.4860
# Epoch: 11/25... Step: 1394... Loss: 1.3290... Val Loss: 1.4865
# Epoch: 11/25... Step: 1396... Loss: 1.3118... Val Loss: 1.4835
# Epoch: 11/25... Step: 1398... Loss: 1.3299... Val Loss: 1.4840
# Epoch: 11/25... Step: 1400... Loss: 1.3548... Val Loss: 1.4841
# Epoch: 11/25... Step: 1402... Loss: 1.3317... Val Loss: 1.4835
# Epoch: 11/25... Step: 1404... Loss: 1.3228... Val Loss: 1.4797
# Epoch: 11/25... Step: 1406... Loss: 1.3128... Val Loss: 1.4799
# Epoch: 11/25... Step: 1408... Loss: 1.3306... Val Loss: 1.4773
# Epoch: 11/25... Step: 1410... Loss: 1.3622... Val Loss: 1.4812
# Epoch: 11/25... Step: 1412... Loss: 1.3111... Val Loss: 1.4773
# Epoch: 11/25... Step: 1414... Loss: 1.3199... Val Loss: 1.4766
# Epoch: 11/25... Step: 1416... Loss: 1.2977... Val Loss: 1.4782
# Epoch: 11/25... Step: 1418... Loss: 1.3379... Val Loss: 1.4804
# Epoch: 11/25... Step: 1420... Loss: 1.3633... Val Loss: 1.4761
# Epoch: 11/25... Step: 1422... Loss: 1.3113... Val Loss: 1.4766
# Epoch: 11/25... Step: 1424... Loss: 1.3054... Val Loss: 1.4866
# Epoch: 11/25... Step: 1426... Loss: 1.3056... Val Loss: 1.4840
# Epoch: 11/25... Step: 1428... Loss: 1.3525... Val Loss: 1.4805
# Epoch: 11/25... Step: 1430... Loss: 1.3206... Val Loss: 1.4761
# Epoch: 11/25... Step: 1432... Loss: 1.2831... Val Loss: 1.4816
# Epoch: 11/25... Step: 1434... Loss: 1.3106... Val Loss: 1.4852
# Epoch: 11/25... Step: 1436... Loss: 1.3173... Val Loss: 1.4863
# Epoch: 11/25... Step: 1438... Loss: 1.3028... Val Loss: 1.4847
# Epoch: 11/25... Step: 1440... Loss: 1.3441... Val Loss: 1.4837
# Epoch: 11/25... Step: 1442... Loss: 1.3051... Val Loss: 1.4779
# Epoch: 11/25... Step: 1444... Loss: 1.2865... Val Loss: 1.4782
# Epoch: 11/25... Step: 1446... Loss: 1.3311... Val Loss: 1.4803
# Epoch: 11/25... Step: 1448... Loss: 1.3266... Val Loss: 1.4744
# Epoch: 11/25... Step: 1450... Loss: 1.2873... Val Loss: 1.4770
# Epoch: 11/25... Step: 1452... Loss: 1.3264... Val Loss: 1.4755
# Epoch: 11/25... Step: 1454... Loss: 1.3184... Val Loss: 1.4756
# Epoch: 11/25... Step: 1456... Loss: 1.3272... Val Loss: 1.4729
# Epoch: 11/25... Step: 1458... Loss: 1.3122... Val Loss: 1.4809
# Epoch: 11/25... Step: 1460... Loss: 1.3058... Val Loss: 1.4741
# Epoch: 11/25... Step: 1462... Loss: 1.3126... Val Loss: 1.4763
# Epoch: 11/25... Step: 1464... Loss: 1.3348... Val Loss: 1.4743
# Epoch: 11/25... Step: 1466... Loss: 1.2893... Val Loss: 1.4844
# Epoch: 11/25... Step: 1468... Loss: 1.3372... Val Loss: 1.4739
# Epoch: 11/25... Step: 1470... Loss: 1.3077... Val Loss: 1.4727
# Epoch: 11/25... Step: 1472... Loss: 1.2782... Val Loss: 1.4796
# Epoch: 11/25... Step: 1474... Loss: 1.2983... Val Loss: 1.4833
# Epoch: 11/25... Step: 1476... Loss: 1.3126... Val Loss: 1.4751
# Epoch: 11/25... Step: 1478... Loss: 1.3014... Val Loss: 1.4724
# Epoch: 11/25... Step: 1480... Loss: 1.3146... Val Loss: 1.4781
# Epoch: 11/25... Step: 1482... Loss: 1.3133... Val Loss: 1.4816
# Epoch: 11/25... Step: 1484... Loss: 1.3101... Val Loss: 1.4702
# Epoch: 11/25... Step: 1486... Loss: 1.2928... Val Loss: 1.4739
# Epoch: 11/25... Step: 1488... Loss: 1.2973... Val Loss: 1.4801
# Epoch: 11/25... Step: 1490... Loss: 1.3006... Val Loss: 1.4858
# Epoch: 11/25... Step: 1492... Loss: 1.3262... Val Loss: 1.4742
# Epoch: 11/25... Step: 1494... Loss: 1.2966... Val Loss: 1.4741
# Epoch: 11/25... Step: 1496... Loss: 1.2993... Val Loss: 1.4769
# Epoch: 11/25... Step: 1498... Loss: 1.3153... Val Loss: 1.4830
# Epoch: 11/25... Step: 1500... Loss: 1.2969... Val Loss: 1.4831
# Epoch: 11/25... Step: 1502... Loss: 1.3018... Val Loss: 1.4739
# Epoch: 11/25... Step: 1504... Loss: 1.3076... Val Loss: 1.4773
# Epoch: 11/25... Step: 1506... Loss: 1.3244... Val Loss: 1.4719
# Epoch: 11/25... Step: 1508... Loss: 1.2856... Val Loss: 1.4709
# Epoch: 11/25... Step: 1510... Loss: 1.2735... Val Loss: 1.4676
# Epoch: 11/25... Step: 1512... Loss: 1.2871... Val Loss: 1.4788
# Epoch: 11/25... Step: 1514... Loss: 1.3208... Val Loss: 1.4807
# Epoch: 11/25... Step: 1516... Loss: 1.3261... Val Loss: 1.4765
# Epoch: 11/25... Step: 1518... Loss: 1.3054... Val Loss: 1.4747
# Epoch: 11/25... Step: 1520... Loss: 1.3188... Val Loss: 1.4828
# Epoch: 11/25... Step: 1522... Loss: 1.3098... Val Loss: 1.4774
# Epoch: 11/25... Step: 1524... Loss: 1.3077... Val Loss: 1.4728
# Epoch: 11/25... Step: 1526... Loss: 1.3295... Val Loss: 1.4724
# Epoch: 11/25... Step: 1528... Loss: 1.3197... Val Loss: 1.4764
# Epoch: 12/25... Step: 1530... Loss: 1.3663... Val Loss: 1.4721
# Epoch: 12/25... Step: 1532... Loss: 1.3183... Val Loss: 1.4709
# Epoch: 12/25... Step: 1534... Loss: 1.3172... Val Loss: 1.4736
# Epoch: 12/25... Step: 1536... Loss: 1.2894... Val Loss: 1.4800
# Epoch: 12/25... Step: 1538... Loss: 1.3193... Val Loss: 1.4728
# Epoch: 12/25... Step: 1540... Loss: 1.3216... Val Loss: 1.4717
# Epoch: 12/25... Step: 1542... Loss: 1.2987... Val Loss: 1.4671
# Epoch: 12/25... Step: 1544... Loss: 1.2943... Val Loss: 1.4759
# Epoch: 12/25... Step: 1546... Loss: 1.2969... Val Loss: 1.4665
# Epoch: 12/25... Step: 1548... Loss: 1.3250... Val Loss: 1.4637
# Epoch: 12/25... Step: 1550... Loss: 1.3261... Val Loss: 1.4702
# Epoch: 12/25... Step: 1552... Loss: 1.3293... Val Loss: 1.4627
# Epoch: 12/25... Step: 1554... Loss: 1.2961... Val Loss: 1.4628
# Epoch: 12/25... Step: 1556... Loss: 1.2981... Val Loss: 1.4691
# Epoch: 12/25... Step: 1558... Loss: 1.3257... Val Loss: 1.4674
# Epoch: 12/25... Step: 1560... Loss: 1.3436... Val Loss: 1.4572
# Epoch: 12/25... Step: 1562... Loss: 1.2652... Val Loss: 1.4643
# Epoch: 12/25... Step: 1564... Loss: 1.3158... Val Loss: 1.4644
# Epoch: 12/25... Step: 1566... Loss: 1.3243... Val Loss: 1.4661
# Epoch: 12/25... Step: 1568... Loss: 1.3066... Val Loss: 1.4611
# Epoch: 12/25... Step: 1570... Loss: 1.2842... Val Loss: 1.4614
# Epoch: 12/25... Step: 1572... Loss: 1.2474... Val Loss: 1.4648
# Epoch: 12/25... Step: 1574... Loss: 1.2790... Val Loss: 1.4679
# Epoch: 12/25... Step: 1576... Loss: 1.3129... Val Loss: 1.4651
# Epoch: 12/25... Step: 1578... Loss: 1.3068... Val Loss: 1.4654
# Epoch: 12/25... Step: 1580... Loss: 1.2796... Val Loss: 1.4669
# Epoch: 12/25... Step: 1582... Loss: 1.3044... Val Loss: 1.4630
# Epoch: 12/25... Step: 1584... Loss: 1.2874... Val Loss: 1.4634
# Epoch: 12/25... Step: 1586... Loss: 1.3017... Val Loss: 1.4671
# Epoch: 12/25... Step: 1588... Loss: 1.3076... Val Loss: 1.4608
# Epoch: 12/25... Step: 1590... Loss: 1.2650... Val Loss: 1.4681
# Epoch: 12/25... Step: 1592... Loss: 1.3146... Val Loss: 1.4697
# Epoch: 12/25... Step: 1594... Loss: 1.3111... Val Loss: 1.4624
# Epoch: 12/25... Step: 1596... Loss: 1.3011... Val Loss: 1.4536
# Epoch: 12/25... Step: 1598... Loss: 1.2812... Val Loss: 1.4592
# Epoch: 12/25... Step: 1600... Loss: 1.2857... Val Loss: 1.4646
# Epoch: 12/25... Step: 1602... Loss: 1.3037... Val Loss: 1.4708
# Epoch: 12/25... Step: 1604... Loss: 1.2892... Val Loss: 1.4688
# Epoch: 12/25... Step: 1606... Loss: 1.2801... Val Loss: 1.4639
# Epoch: 12/25... Step: 1608... Loss: 1.2807... Val Loss: 1.4603
# Epoch: 12/25... Step: 1610... Loss: 1.2791... Val Loss: 1.4647
# Epoch: 12/25... Step: 1612... Loss: 1.3178... Val Loss: 1.4621
# Epoch: 12/25... Step: 1614... Loss: 1.2919... Val Loss: 1.4656
# Epoch: 12/25... Step: 1616... Loss: 1.2758... Val Loss: 1.4668
# Epoch: 12/25... Step: 1618... Loss: 1.2772... Val Loss: 1.4610
# Epoch: 12/25... Step: 1620... Loss: 1.2755... Val Loss: 1.4661
# Epoch: 12/25... Step: 1622... Loss: 1.2930... Val Loss: 1.4594
# Epoch: 12/25... Step: 1624... Loss: 1.2841... Val Loss: 1.4627
# Epoch: 12/25... Step: 1626... Loss: 1.2888... Val Loss: 1.4604
# Epoch: 12/25... Step: 1628... Loss: 1.2689... Val Loss: 1.4727
# Epoch: 12/25... Step: 1630... Loss: 1.3098... Val Loss: 1.4583
# Epoch: 12/25... Step: 1632... Loss: 1.2954... Val Loss: 1.4650
# Epoch: 12/25... Step: 1634... Loss: 1.3063... Val Loss: 1.4655
# Epoch: 12/25... Step: 1636... Loss: 1.2816... Val Loss: 1.4669
# Epoch: 12/25... Step: 1638... Loss: 1.2822... Val Loss: 1.4696
# Epoch: 12/25... Step: 1640... Loss: 1.2742... Val Loss: 1.4625
# Epoch: 12/25... Step: 1642... Loss: 1.2974... Val Loss: 1.4629
# Epoch: 12/25... Step: 1644... Loss: 1.2821... Val Loss: 1.4654
# Epoch: 12/25... Step: 1646... Loss: 1.2825... Val Loss: 1.4584
# Epoch: 12/25... Step: 1648... Loss: 1.2718... Val Loss: 1.4615
# Epoch: 12/25... Step: 1650... Loss: 1.2643... Val Loss: 1.4647
# Epoch: 12/25... Step: 1652... Loss: 1.2569... Val Loss: 1.4581
# Epoch: 12/25... Step: 1654... Loss: 1.2416... Val Loss: 1.4571
# Epoch: 12/25... Step: 1656... Loss: 1.2709... Val Loss: 1.4595
# Epoch: 12/25... Step: 1658... Loss: 1.3049... Val Loss: 1.4558
# Epoch: 12/25... Step: 1660... Loss: 1.3108... Val Loss: 1.4537
# Epoch: 12/25... Step: 1662... Loss: 1.3137... Val Loss: 1.4554
# Epoch: 12/25... Step: 1664... Loss: 1.2982... Val Loss: 1.4541
# Epoch: 12/25... Step: 1666... Loss: 1.2780... Val Loss: 1.4532
# Epoch: 12/25... Step: 1668... Loss: 1.3214... Val Loss: 1.4561
# Epoch: 13/25... Step: 1670... Loss: 1.2804... Val Loss: 1.4579
# Epoch: 13/25... Step: 1672... Loss: 1.2730... Val Loss: 1.4554
# Epoch: 13/25... Step: 1674... Loss: 1.2650... Val Loss: 1.4585
# Epoch: 13/25... Step: 1676... Loss: 1.2860... Val Loss: 1.4568
# Epoch: 13/25... Step: 1678... Loss: 1.3102... Val Loss: 1.4601
# Epoch: 13/25... Step: 1680... Loss: 1.2893... Val Loss: 1.4559
# Epoch: 13/25... Step: 1682... Loss: 1.2771... Val Loss: 1.4565
# Epoch: 13/25... Step: 1684... Loss: 1.2715... Val Loss: 1.4549
# Epoch: 13/25... Step: 1686... Loss: 1.3005... Val Loss: 1.4512
# Epoch: 13/25... Step: 1688... Loss: 1.3218... Val Loss: 1.4536
# Epoch: 13/25... Step: 1690... Loss: 1.2682... Val Loss: 1.4531
# Epoch: 13/25... Step: 1692... Loss: 1.2782... Val Loss: 1.4507
# Epoch: 13/25... Step: 1694... Loss: 1.2572... Val Loss: 1.4576
# Epoch: 13/25... Step: 1696... Loss: 1.3060... Val Loss: 1.4535
# Epoch: 13/25... Step: 1698... Loss: 1.3248... Val Loss: 1.4489
# Epoch: 13/25... Step: 1700... Loss: 1.2717... Val Loss: 1.4510
# Epoch: 13/25... Step: 1702... Loss: 1.2657... Val Loss: 1.4595
# Epoch: 13/25... Step: 1704... Loss: 1.2703... Val Loss: 1.4649
# Epoch: 13/25... Step: 1706... Loss: 1.3040... Val Loss: 1.4594
# Epoch: 13/25... Step: 1708... Loss: 1.2907... Val Loss: 1.4555
# Epoch: 13/25... Step: 1710... Loss: 1.2536... Val Loss: 1.4541
# Epoch: 13/25... Step: 1712... Loss: 1.2733... Val Loss: 1.4585
# Epoch: 13/25... Step: 1714... Loss: 1.2778... Val Loss: 1.4583
# Epoch: 13/25... Step: 1716... Loss: 1.2751... Val Loss: 1.4585
# Epoch: 13/25... Step: 1718... Loss: 1.2978... Val Loss: 1.4577
# Epoch: 13/25... Step: 1720... Loss: 1.2587... Val Loss: 1.4667
# Epoch: 13/25... Step: 1722... Loss: 1.2562... Val Loss: 1.4605
# Epoch: 13/25... Step: 1724... Loss: 1.2898... Val Loss: 1.4695
# Epoch: 13/25... Step: 1726... Loss: 1.2832... Val Loss: 1.4623
# Epoch: 13/25... Step: 1728... Loss: 1.2476... Val Loss: 1.4638
# Epoch: 13/25... Step: 1730... Loss: 1.2994... Val Loss: 1.4606
# Epoch: 13/25... Step: 1732... Loss: 1.2803... Val Loss: 1.4648
# Epoch: 13/25... Step: 1734... Loss: 1.2911... Val Loss: 1.4493
# Epoch: 13/25... Step: 1736... Loss: 1.2683... Val Loss: 1.4418
# Epoch: 13/25... Step: 1738... Loss: 1.2699... Val Loss: 1.4437
# Epoch: 13/25... Step: 1740... Loss: 1.2707... Val Loss: 1.4455
# Epoch: 13/25... Step: 1742... Loss: 1.2893... Val Loss: 1.4515
# Epoch: 13/25... Step: 1744... Loss: 1.2497... Val Loss: 1.4526
# Epoch: 13/25... Step: 1746... Loss: 1.3073... Val Loss: 1.4496
# Epoch: 13/25... Step: 1748... Loss: 1.2557... Val Loss: 1.4488
# Epoch: 13/25... Step: 1750... Loss: 1.2434... Val Loss: 1.4536
# Epoch: 13/25... Step: 1752... Loss: 1.2703... Val Loss: 1.4557
# Epoch: 13/25... Step: 1754... Loss: 1.2708... Val Loss: 1.4636
# Epoch: 13/25... Step: 1756... Loss: 1.2682... Val Loss: 1.4552
# Epoch: 13/25... Step: 1758... Loss: 1.2877... Val Loss: 1.4584
# Epoch: 13/25... Step: 1760... Loss: 1.2690... Val Loss: 1.4549
# Epoch: 13/25... Step: 1762... Loss: 1.2795... Val Loss: 1.4423
# Epoch: 13/25... Step: 1764... Loss: 1.2663... Val Loss: 1.4490
# Epoch: 13/25... Step: 1766... Loss: 1.2684... Val Loss: 1.4504
# Epoch: 13/25... Step: 1768... Loss: 1.2702... Val Loss: 1.4461
# Epoch: 13/25... Step: 1770... Loss: 1.3009... Val Loss: 1.4500
# Epoch: 13/25... Step: 1772... Loss: 1.2671... Val Loss: 1.4518
# Epoch: 13/25... Step: 1774... Loss: 1.2637... Val Loss: 1.4554
# Epoch: 13/25... Step: 1776... Loss: 1.2747... Val Loss: 1.4488
# Epoch: 13/25... Step: 1778... Loss: 1.2571... Val Loss: 1.4547
# Epoch: 13/25... Step: 1780... Loss: 1.2586... Val Loss: 1.4585
# Epoch: 13/25... Step: 1782... Loss: 1.2733... Val Loss: 1.4508
# Epoch: 13/25... Step: 1784... Loss: 1.2794... Val Loss: 1.4546
# Epoch: 13/25... Step: 1786... Loss: 1.2641... Val Loss: 1.4471
# Epoch: 13/25... Step: 1788... Loss: 1.2420... Val Loss: 1.4465
# Epoch: 13/25... Step: 1790... Loss: 1.2413... Val Loss: 1.4497
# Epoch: 13/25... Step: 1792... Loss: 1.2835... Val Loss: 1.4513
# Epoch: 13/25... Step: 1794... Loss: 1.2828... Val Loss: 1.4413
# Epoch: 13/25... Step: 1796... Loss: 1.2616... Val Loss: 1.4393
# Epoch: 13/25... Step: 1798... Loss: 1.2781... Val Loss: 1.4420
# Epoch: 13/25... Step: 1800... Loss: 1.2620... Val Loss: 1.4404
# Epoch: 13/25... Step: 1802... Loss: 1.2667... Val Loss: 1.4360
# Epoch: 13/25... Step: 1804... Loss: 1.2810... Val Loss: 1.4376
# Epoch: 13/25... Step: 1806... Loss: 1.2654... Val Loss: 1.4440
# Epoch: 14/25... Step: 1808... Loss: 1.3290... Val Loss: 1.4431
# Epoch: 14/25... Step: 1810... Loss: 1.2907... Val Loss: 1.4420
# Epoch: 14/25... Step: 1812... Loss: 1.2931... Val Loss: 1.4429
# Epoch: 14/25... Step: 1814... Loss: 1.2491... Val Loss: 1.4552
# Epoch: 14/25... Step: 1816... Loss: 1.2832... Val Loss: 1.4508
# Epoch: 14/25... Step: 1818... Loss: 1.2837... Val Loss: 1.4445
# Epoch: 14/25... Step: 1820... Loss: 1.2615... Val Loss: 1.4410
# Epoch: 14/25... Step: 1822... Loss: 1.2575... Val Loss: 1.4376
# Epoch: 14/25... Step: 1824... Loss: 1.2616... Val Loss: 1.4399
# Epoch: 14/25... Step: 1826... Loss: 1.2834... Val Loss: 1.4412
# Epoch: 14/25... Step: 1828... Loss: 1.2847... Val Loss: 1.4377
# Epoch: 14/25... Step: 1830... Loss: 1.2881... Val Loss: 1.4439
# Epoch: 14/25... Step: 1832... Loss: 1.2597... Val Loss: 1.4380
# Epoch: 14/25... Step: 1834... Loss: 1.2657... Val Loss: 1.4395
# Epoch: 14/25... Step: 1836... Loss: 1.2853... Val Loss: 1.4413
# Epoch: 14/25... Step: 1838... Loss: 1.3033... Val Loss: 1.4403
# Epoch: 14/25... Step: 1840... Loss: 1.2388... Val Loss: 1.4404
# Epoch: 14/25... Step: 1842... Loss: 1.2746... Val Loss: 1.4414
# Epoch: 14/25... Step: 1844... Loss: 1.2773... Val Loss: 1.4442
# Epoch: 14/25... Step: 1846... Loss: 1.2757... Val Loss: 1.4452
# Epoch: 14/25... Step: 1848... Loss: 1.2535... Val Loss: 1.4336
# Epoch: 14/25... Step: 1850... Loss: 1.2172... Val Loss: 1.4381
# Epoch: 14/25... Step: 1852... Loss: 1.2513... Val Loss: 1.4432
# Epoch: 14/25... Step: 1854... Loss: 1.2705... Val Loss: 1.4465
# Epoch: 14/25... Step: 1856... Loss: 1.2671... Val Loss: 1.4431
# Epoch: 14/25... Step: 1858... Loss: 1.2384... Val Loss: 1.4435
# Epoch: 14/25... Step: 1860... Loss: 1.2738... Val Loss: 1.4468
# Epoch: 14/25... Step: 1862... Loss: 1.2571... Val Loss: 1.4411
# Epoch: 14/25... Step: 1864... Loss: 1.2705... Val Loss: 1.4361
# Epoch: 14/25... Step: 1866... Loss: 1.2699... Val Loss: 1.4512
# Epoch: 14/25... Step: 1868... Loss: 1.2242... Val Loss: 1.4488
# Epoch: 14/25... Step: 1870... Loss: 1.2772... Val Loss: 1.4446
# Epoch: 14/25... Step: 1872... Loss: 1.2819... Val Loss: 1.4364
# Epoch: 14/25... Step: 1874... Loss: 1.2644... Val Loss: 1.4327
# Epoch: 14/25... Step: 1876... Loss: 1.2445... Val Loss: 1.4343
# Epoch: 14/25... Step: 1878... Loss: 1.2578... Val Loss: 1.4315
# Epoch: 14/25... Step: 1880... Loss: 1.2715... Val Loss: 1.4379
# Epoch: 14/25... Step: 1882... Loss: 1.2500... Val Loss: 1.4445
# Epoch: 14/25... Step: 1884... Loss: 1.2440... Val Loss: 1.4390
# Epoch: 14/25... Step: 1886... Loss: 1.2437... Val Loss: 1.4406
# Epoch: 14/25... Step: 1888... Loss: 1.2464... Val Loss: 1.4391
# Epoch: 14/25... Step: 1890... Loss: 1.2734... Val Loss: 1.4367
# Epoch: 14/25... Step: 1892... Loss: 1.2616... Val Loss: 1.4422
# Epoch: 14/25... Step: 1894... Loss: 1.2411... Val Loss: 1.4403
# Epoch: 14/25... Step: 1896... Loss: 1.2369... Val Loss: 1.4386
# Epoch: 14/25... Step: 1898... Loss: 1.2323... Val Loss: 1.4458
# Epoch: 14/25... Step: 1900... Loss: 1.2564... Val Loss: 1.4415
# Epoch: 14/25... Step: 1902... Loss: 1.2511... Val Loss: 1.4343
# Epoch: 14/25... Step: 1904... Loss: 1.2650... Val Loss: 1.4318
# Epoch: 14/25... Step: 1906... Loss: 1.2364... Val Loss: 1.4364
# Epoch: 14/25... Step: 1908... Loss: 1.2669... Val Loss: 1.4369
# Epoch: 14/25... Step: 1910... Loss: 1.2539... Val Loss: 1.4380
# Epoch: 14/25... Step: 1912... Loss: 1.2659... Val Loss: 1.4316
# Epoch: 14/25... Step: 1914... Loss: 1.2569... Val Loss: 1.4381

# %% [markdown]
# ## Getting the best model
#
# To set your hyperparameters to get the best performance, you'll want to watch the training and validation losses. If your training loss is much lower than the validation loss, you're overfitting. Increase regularization (more dropout) or use a smaller network. If the training and validation losses are close, you're underfitting so you can increase the size of the network.

# %% [markdown]
# ## Hyperparameters
#
# Here are the hyperparameters for the network.
#
# In defining the model:
# * `n_hidden` - The number of units in the hidden layers.
# * `n_layers` - Number of hidden LSTM layers to use.
#
# We assume that dropout probability and learning rate will be kept at the default, in this example.
#
# And in training:
# * `n_seqs` - Number of sequences running through the network in one pass.
# * `n_steps` - Number of characters in the sequence the network is trained on. Larger is better typically, the network will learn more long range dependencies. But it takes longer to train. 100 is typically a good number here.
# * `lr` - Learning rate for training
#
# Here's some good advice from Andrej Karpathy on training the network. I'm going to copy it in here for your benefit, but also link to [where it originally came from](https://github.com/karpathy/char-rnn#tips-and-tricks).
#
# > ## Tips and Tricks
#
# >### Monitoring Validation Loss vs. Training Loss
# >If you're somewhat new to Machine Learning or Neural Networks it can take a bit of expertise to get good models. The most important quantity to keep track of is the difference between your training loss (printed during training) and the validation loss (printed once in a while when the RNN is run on the validation data (by default every 1000 iterations)). In particular:
#
# > - If your training loss is much lower than validation loss then this means the network might be **overfitting**. Solutions to this are to decrease your network size, or to increase dropout. For example you could try dropout of 0.5 and so on.
# > - If your training/validation loss are about equal then your model is **underfitting**. Increase the size of your model (either number of layers or the raw number of neurons per layer)
#
# > ### Approximate number of parameters
#
# > The two most important parameters that control the model are `n_hidden` and `n_layers`. I would advise that you always use `n_layers` of either 2/3. The `n_hidden` can be adjusted based on how much data you have. The two important quantities to keep track of here are:
#
# > - The number of parameters in your model. This is printed when you start training.
# > - The size of your dataset. 1MB file is approximately 1 million characters.
#
# >These two should be about the same order of magnitude. It's a little tricky to tell. Here are some examples:
#
# > - I have a 100MB dataset and I'm using the default parameter settings (which currently print 150K parameters). My data size is significantly larger (100 mil >> 0.15 mil), so I expect to heavily underfit. I am thinking I can comfortably afford to make `n_hidden` larger.
# > - I have a 10MB dataset and running a 10 million parameter model. I'm slightly nervous and I'm carefully monitoring my validation loss. If it's larger than my training loss then I may want to try to increase dropout a bit and see if that helps the validation loss.
#
# > ### Best models strategy
#
# >The winning strategy to obtaining very good models (if you have the compute time) is to always err on making the network larger (as large as you're willing to wait for it to compute) and then try different dropout values (between 0,1). Whatever model has the best validation performance (the loss, written in the checkpoint filename, low is good) is the one you should use in the end.
#
# >It is very common in deep learning to run many different models with many different hyperparameter settings, and in the end take whatever checkpoint gave the best validation performance.
#
# >By the way, the size of your training and validation splits are also parameters. Make sure you have a decent amount of data in your validation set or otherwise the validation performance will be noisy and not very informative.

# %% [markdown]
# After training, we'll save the model so we can load it again later if we need too. Here I'm saving the parameters needed to create the same architecture, the hidden layer hyperparameters and the text characters.

# %%
# change the name, for saving multiple files
model_name = 'rnn_1_epoch.net'

checkpoint = {'n_hidden': net.n_hidden,
              'n_layers': net.n_layers,
              'state_dict': net.state_dict(),
              'tokens': net.chars}

with open(model_name, 'wb') as f:
    torch.save(checkpoint, f)

# %% [markdown]
# ## Sampling
#
# Now that the model is trained, we'll want to sample from it. To sample, we pass in a character and have the network predict the next character. Then we take that character, pass it back in, and get another predicted character. Just keep doing this and you'll generate a bunch of text!
#
# ### Top K sampling
#
# Our predictions come from a categorcial probability distribution over all the possible characters. We can make the sample text and make it more reasonable to handle (with less variables) by only considering some $K$ most probable characters. This will prevent the network from giving us completely absurd characters while allowing it to introduce some noise and randomness into the sampled text.
#
# Typically you'll want to prime the network so you can build up a hidden state. Otherwise the network will start out generating characters at random. In general the first bunch of characters will be a little rough since it hasn't built up a long history of characters to predict from.

# %%
def sample(net, size, prime='The', top_k=None, cuda=False):
        
    if cuda:
        net.cuda()
    else:
        net.cpu()

    net.eval()
    
    # First off, run through the prime characters
    chars = [ch for ch in prime]
    h = net.init_hidden(1)
    for ch in prime:
        char, h = net.predict(ch, h, cuda=cuda, top_k=top_k)

    chars.append(char)
    
    # Now pass in the previous character and get a new one
    for ii in range(size):
        char, h = net.predict(chars[-1], h, cuda=cuda, top_k=top_k)
        chars.append(char)

    return ''.join(chars)

# %%
print(sample(net, 2000, prime='Anna', top_k=5, cuda=False))

# %% [markdown]
# ## Loading a checkpoint

# %%
# Here we have loaded in a model that trained over 1 epoch `rnn_1_epoch.net`
with open('rnn_1_epoch.net', 'rb') as f:
    checkpoint = torch.load(f)
    
loaded = CharRNN(checkpoint['tokens'], n_hidden=checkpoint['n_hidden'], n_layers=checkpoint['n_layers'])
loaded.load_state_dict(checkpoint['state_dict'])

# %%
# Change cuda to True if you are using GPU!
print(sample(loaded, 2000, cuda=True, top_k=5, prime="And Levin said"))
